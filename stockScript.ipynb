# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

from concurrent import futures
import numpy as np
from scipy.stats import gaussian_kde
import pandas_datareader.data as web
import yfinance as yf

data_dir = "./data/stock_data_for_finding_attractive_stocks"
os.makedirs(data_dir, exist_ok=True)

current_day = str(dt.date.today()).replace('-','')
start_time = dt.date(1980, 1, 1)
end_time = dt.date.today()

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
sp500_df = tables[0]
second_table = tables[1]
print(sp500_df.shape)
sp500_df["Symbol"] = sp500_df["Symbol"].map(lambda x: x.replace(".", "-"))  # rename symbol to escape symbol error
sp500_df.to_csv("./data/SP500_%s.csv" % current_day, index=False)
sp500_df = pd.read_csv("./data/SP500_%s.csv" % current_day)
print(sp500_df.shape)
sp500_tickers = list(sp500_df["Symbol"])
sp500_df.head()
# Out:
# (504, 9)
# (504, 9)
#   Symbol     Security SEC filings  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M     reports  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith     reports  Industrials         Building Products
# 2    ABT       Abbott     reports  Health Care     Health Care Equipment
# 3   ABBV       AbbVie     reports  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed     reports  Health Care     Health Care Equipment
#
#      Headquarters Location Date first added      CIK      Founded
# 0    Saint Paul, Minnesota       1976-08-09    66740         1902
# 1     Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2  North Chicago, Illinois       1964-03-31     1800         1888
# 3  North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4   Danvers, Massachusetts       2018-05-31   815094         1981

# %%
def download_stock(stock):
    try:
        stock_df = yf.download(stock, start_time, end_time)
        print(stock_df)
        stock_df['Name'] = stock
        output_name = f"{data_dir}/{stock}.csv"
        stock_df.to_csv(output_name)
    except:
        bad_names.append(stock)
        print('bad: %s' % (stock))

        
""" set the download window """
bad_names =[] #to keep track of failed queries
#set the maximum thread number
max_workers = 100000
#now = dt.datetime.now()
path_failed_queries = f'{data_dir}/failed_queries.txt'

if os.path.exists(path_failed_queries):
    with open(path_failed_queries) as f:
        failed_queries = f.read().split("\n")[:-1]
        sp500_tickers_ = failed_queries

else:
    sp500_tickers_ = sp500_tickers

print("number of stocks to download:", len(sp500_tickers_))
#workers = min(max_workers, len(sp500_tickers_)) #in case a smaller number of stocks than threads was passed in
workers = max_workers

with futures.ThreadPoolExecutor(workers) as executor:
    res = executor.map(download_stock, sp500_tickers_)

""" Save failed queries to a text file to retry """
if len(bad_names) > 0:
    with open(path_failed_queries, 'w') as outfile:
        for name in bad_names:
            outfile.write(name+'\n')

while len(bad_names) > 0:
    with futures.ThreadPoolExecutor(workers) as executor:
        res = executor.map(download_stock, sp500_tickers_)
#finish_time = dt.datetime.now()
#duration = finish_time - now
#minutes, seconds = divmod(duration.seconds, 60)
#print(f'The threaded script took {minutes} minutes and {seconds} seconds to run.')
print(f"{len(bad_names)} stocks failed: ", bad_names)
# Out:
# number of stocks to download: 453
# [*********************100%***********************]  1 of 1 completed
# bad: EBAY
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: FANG
#
#
# bad: MDLZ
#
#
#
# bad: ISRG
#
# bad: MMM
#
# bad: DIS
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
# bad: ZBH
#
#
#
#
# bad: ILMN
#
#
#
# bad: K
#
# bad: DOV
#
#
#
#
#
#
#
#
# bad: MRK
#
#
#
#
# bad: HPQ
#
#
#
#
#
#
#
#
# bad: ZION
#
#
#
# bad: ADI
#
# bad: ES
#
# bad: KR
#
#
#
#
#
#
#
#
#
# bad: PSA
#
#
# bad: LRCX
#
# bad: KEY
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: APA
#
#
#
# bad: RL
#
#
#
#
#
#
#
#
#
#
# bad: EMR
#
# bad: USB
#
#
#
#
#
#
#
#
# bad: ADP
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
# bad: COO
#
# bad: BBWI
#
# bad: DGX
#
# bad: CDNS
#
#
# bad: UPS
#
# bad: UNH
#
#
#
# bad: PPL
#
# bad: BLK
#
#
#
# bad: INCY
#
#
#
#
#
#
#
# bad: TTWObad: ALL
#
#
#
# bad: EVRGbad: RCLbad: PLD
#
# bad: LYB
#
#
#
#
#
#
# bad: MSCIbad: AJGbad: LNTbad: FCXbad: OTIS
#
#
#
# bad: XOM
#
# bad: UDR
# bad: MAbad: EOGbad: SWKSbad: ABMD
#
# bad: FTV
# bad: CTSH
#
#
#
#
# bad: APH
# bad: MTBbad: CMSbad: PRUbad: NTAPbad: PFE
#
#
# bad: NOC
#
# bad: EMN
# bad: SWK
# bad: KMI
# bad: DTE
# bad: AVY
# bad: TECH
# bad: PKG
#
# bad: DLTR
#
# bad: BF-B
# bad: MS
# bad: GOOGL
# bad: UHS
#
#
# bad: CVX
# bad: LYVbad: SEDGbad: BDX
# bad: HAS
# bad: ED
#
# bad: ARE
# bad: VZbad: ITbad: MRO
#
#
#
# bad: WELL
#
# bad: MTCH
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
# bad: EXPDbad: FDSbad: TSN
# [*********************100%***********************]  1 of 1 completed
# bad: SO
# bad: GLWbad: LHX
# bad: CPT
#
# bad: CME
# bad: MGMbad: TT
#
# bad: MOH
#
#
#
# bad: FASTbad: CARRbad: MCHPbad: NCLH
#
#
#
# bad: WRK
# bad: VMC
#
# bad: PMbad: KMB
# bad: NI
# bad: EW
#
# bad: BENbad: JKHY
# bad: WBA
# bad: NFLXbad: WMTbad: ETSYbad: CBbad: DHI
#
#
# bad: NSC
# bad: PNWbad: CSCO
#
# bad: NOW
#
#
#
# bad: KLAC
#
# bad: STZ
# bad: VFC
#
#
# bad: PXDbad: CTAS
#
# bad: COP
#
# bad: SNA
# bad: EXPEbad: SYK
#
# bad: OKE
#
# bad: CINF
#
# bad: HBANbad: ETR
# bad: FB
# bad: AME
# bad: IRM
# bad: TWTRbad: IEX
#
# bad: CHRW
#
# bad: V
#
# bad: WMB
# bad: HIIbad: DHR
#
#
#
# bad: BWA
# bad: HWM
#
# bad: SCHWbad: NVR
# bad: LMT
# bad: WY
# bad: GM
#
#
# bad: AAL
#
#
#
#
#
# bad: UAA
# bad: NTRSbad: FITB
#
# bad: AEP
#
# bad: FTNTbad: HRLbad: URIbad: UAL
# bad: ICEbad: SPGI
#
# bad: LNC
#
#
# bad: WAT
# bad: BSX
# bad: JNPR
# bad: FMCbad: BRbad: HLT
#
# bad: MHK
# bad: ALGNbad: MSI
# bad: COF
# bad: SYYbad: SBUX
#
# bad: CAGbad: CMA
#
# bad: EQIX
#
#
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-01-19  38.000000  43.000000  38.000000  42.000000  42.000000   129900
# 2022-01-20  40.950001  48.369999  40.950001  45.000000  45.000000   153400
# 2022-01-21  43.000000  49.950001  42.950001  45.000000  45.000000   329500
# 2022-01-24  44.919998  45.000000  41.880001  42.799999  42.799999   110000
# 2022-01-25  42.500000  44.919998  41.330002  41.897999  41.897999    23500
# ...               ...        ...        ...        ...        ...      ...
# 2022-04-26  61.799999  62.220001  59.910000  59.950001  59.950001  2136500
# 2022-04-27  60.009998  61.189999  59.730000  60.090000  60.090000  1991600
# 2022-04-28  60.220001  61.349998  58.799999  61.310001  61.310001  3354600
# 2022-04-29  61.500000  61.860001  59.150002  59.209999  59.209999  2578400
# 2022-05-02  59.299999  59.990002  56.900002  58.200001  58.200001  2488200
#
# [72 rows x 6 columns]
#
#
# bad: MAA
#
# bad: LEN
#
# bad: NLSNbad: NEEbad: HON
# bad: EIX
# bad: ECL
#
# bad: CPB
#
#
#
# bad: BXP
# bad: NUE
# bad: EPAMbad: BA
#
#
#
#
# bad: MMCbad: CDAY
#
#
#
#
#
#
#
#
#
# bad: UNP
#
#
#
# bad: HSIC
# bad: EQR
#
#
#
#
# bad: DUK
#
#
#
#
#
#
# bad: CTRA
#
# bad: AZO
#
#
#
#
#
# bad: JCI
#
# bad: CRL
#
#
#
#
#
#
#
#
#
#
# bad: AXP
#
# bad: BBY
#
# bad: DVN
#
#
#
# bad: SYF
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: XYL
#
#
#
#
#
#
#
#
#
#
# bad: MCD
#
# bad: FOXA
#
#
#
#
# bad: LW
#
# bad: PWR
#
#
#
#
#
# bad: BAC
#
# bad: CATbad: LDOS
# bad: SJM
#
# bad: RJFbad: RFbad: BKR
#
#
#
#
# bad: IQVbad: ACNbad: CZRbad: TPRbad: STEbad: IFFbad: BLLbad: MLMbad: BKNGbad: ODFL
# bad: HDbad: KMX
#
# bad: HOLXbad: PARAbad: RSGbad: GLbad: MOS
# bad: O
# bad: ATO
# bad: KIM
#
#
#
#
#
#
#
# bad: HSY
# bad: GPN
# bad: ORLY
# bad: AAPL
#
#
# bad: NKEbad: DFS
# bad: AKAM
#
# bad: WYNNbad: REGN
#
#
#
#
#
#
#
# bad: WST
#
# bad: LHbad: OMC
#
#
#
# bad: HCA
# bad: SBNY
# bad: Tbad: TFXbad: MDT
# bad: TJXbad: HSTbad: IBM
#
#
#
#
#
#
#
#
# bad: TXT
#
# bad: AOS
# bad: TFC
#
# bad: LUMN
#
# bad: CCI
#
# bad: AFL
#
#
#
#
# bad: AMZN
#
#
#
# bad: CTXS
#
# bad: TAP
#
#
# bad: NDSN
#
#
#
# bad: VNO
#
# bad: ANET
#
#
# bad: ADSK
# bad: FISV
#
#
#
#
#
# bad: WFC
# bad: VTRSbad: BAXbad: DVA
#
#
# bad: ABC
#
#
# bad: FFIV
#
# bad: ROLbad: BIIBbad: ABT
# bad: MRNA
#
#
# bad: CLX
# bad: SLB
# bad: EFX
#
#
# bad: TSLA
#
# bad: ITWbad: MUbad: BRObad: PPG
#
# bad: VRTXbad: AONbad: AMGN
# bad: IPbad: CVS
# bad: ALK
#
# bad: REG
#
#
# bad: WTW
# bad: CFG
# bad: NWSbad: JPM
# bad: ADM
#
#
#
#
#
#
#
#
#
#
# bad: DOW
#
#
#
#
#
#
#
# bad: DAL
# bad: PEG
# bad: DPZ
#
#
# bad: JBHT
# bad: DRE
#
#
#
# bad: AMT
#
#
# bad: PGR
#
#
#
#
#
#
# bad: PEP
#
# bad: LOW
#
#
# bad: FIS
#
#
#
#
#
# bad: CHTR
#
#
# bad: IR
#
# bad: NWSA
#
# bad: LLY
#
# bad: UA
#
# bad: ATVI
#
#
# bad: HES
#
# bad: SNPS
#
# bad: APTV
#
# bad: CRM
#
# bad: NDAQ
# bad: TRMBbad: FRC
#
#
#
# bad: INTC
# bad: WM
#
# bad: EL
#
# bad: OGN
#
# bad: TDG
#
# bad: PTC
#
# bad: YUM
#
# bad: TXN
#
#
# bad: LVS
# bad: NXPI
# bad: GNRCbad: PHM
# bad: CTVAbad: PH
# bad: PKI
#
# bad: FRTbad: NEM
#
#
# bad: TEL
#
# bad: TGT
#
# bad: A
#
# bad: CERN
# bad: TMUS
# bad: IDXX
#
#
# bad: D
#
# bad: HUM
#
# bad: GILDbad: FOX
# bad: MCK
# bad: DXCMbad: MAS
#
#
# bad: XRAY
#
# bad: ALBbad: GS
#
#
#
#
# bad: APDbad: GIS
#
#
# bad: ZBRAbad: CDW
# bad: NRG
#
#
# bad: MKTX
#
#
# bad: SEE
#
# bad: AEE
#
#
#
#
#
# bad: KHC
#
#
#
# bad: ROST
#
# bad: C
#
#
# bad: MPWR
#
# bad: SIVB
#
#
#
#
#
# bad: BMY
#
#
#
# bad: RE
# bad: DD
# bad: QCOM
#
#
#
#
#
#
#
# bad: AMD
#
# bad: PVH
#
#
#
# bad: DISH
#
# bad: MAR
# bad: LUVbad: TRVbad: TMObad: CEbad: PAYX
#
#
#
# bad: WECbad: HPEbad: AMATbad: ANSSbad: CNCbad: ROP
#
#
# bad: AIG
# bad: QRVO
# bad: AIZbad: VLO
#
#
#
#
# bad: J
# bad: SBAC
#
#
#
#
# bad: STXbad: WRBbad: AESbad: CAH
#
#
# bad: WHRbad: TYL
#
#
#
# bad: IPG
#
#
# bad: DLR
#
#
#
#
#
#
#
# bad: CMI
#
#
#
#
# bad: HAL
#
#
#
# bad: MET
#
#
# bad: MO
#
#
# bad: RMD
#
#
#
#
# bad: L
#
# bad: EXR
#
# bad: FDX
#
# bad: EA
#
# bad: IVZbad: XELbad: WABbad: CCLbad: AMPbad: GD
#
# bad: PEAK
#
#
# bad: AVGObad: CL
# bad: SPG
# bad: ADBE
# bad: TDY
# bad: BRK-B
# bad: RHIbad: BK
#
#
#
#
#
# bad: NVDA
#
#
#
# bad: ANTMbad: MTDbad: ENPHbad: MCO
# bad: NLOKbad: PNR
#
#
#
#
# bad: PG
#
# bad: CBRE
#
# bad: LINbad: GRMN
# bad: STT
# bad: MNST
# bad: IPGP
#
#
#
#
#
#
#
#
# bad: RTXbad: BIObad: AAP
# bad: EXC
#
#
# bad: GE
#
#
#
#
#
#
#
#
# bad: NWLbad: CHD
#
#
# bad: FE
#
#
# bad: ETN
#
# bad: F
#
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-07-09   10.687500   11.062500   10.562500   11.000000    7.720572
# 1986-07-10   11.062500   11.125000   10.687500   10.937500    7.676701
# 1986-07-11   10.875000   10.937500   10.562500   10.562500    7.413502
# 1986-07-14   10.625000   10.625000   10.125000   10.250000    7.194166
# 1986-07-15   10.187500   10.187500    9.312500    9.937500    6.974835
# ...                ...         ...         ...         ...         ...
# 2022-04-26  565.250000  568.340027  553.309998  553.760010  553.760010
# 2022-04-27  556.190002  563.619995  552.849976  554.080017  554.080017
# 2022-04-28  555.469971  564.799988  545.799988  562.000000  562.000000
# 2022-04-29  560.929993  561.580017  529.700012  531.719971  531.719971
# 2022-05-02  532.229980  539.200012  518.270020  528.950012  528.950012
#
#              Volume
# Date
# 1986-07-09  1116800
# 1986-07-10   595600
# 1986-07-11   800400
# 1986-07-14   738000
# 1986-07-15  2059200
# ...             ...
# 2022-04-26  2057400
# 2022-04-27  2261600
# 2022-04-28  2118700
# 2022-04-29  2964600
# 2022-05-02  3303400
#
# [9028 rows x 6 columns]
# bad: TER
#
# bad: CMCSA
#
# bad: CNP
# [*********************100%***********************]  1 of 1 completed
# bad: CSCO
# [*********************100%***********************]  1 of 1 completed
# bad: UNH
# [*********************100%***********************]  1 of 1 completed
# bad: FRT
# [*********************100%***********************]  1 of 1 completed
#
# bad: PKG
# [*********************100%***********************]  1 of 1 completed
# bad: MDT
#
#
# [*********************100%***********************]  1 of 1 completed
# bad: ATVI
# [*********************100%***********************]  1 of 1 completed
# bad: KEYS
#
# bad: SYF
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
# bad: HON
#
#
# [*********************100%***********************]  1 of 1 completed
#
# bad: LVS
#
#
# bad: TSLA
#
# bad: NLSN
#
# bad: CLX
#
# bad: BBY
#
# bad: VZ
#
# bad: REGN
#
# bad: IR
#
#
# bad: NTRS
#
# bad: FFIV
#
# bad: BIO
#
# bad: IPG
#
#
# bad: HLT
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: FCX
#
#
#
#
#
#
#
#
#
#
#
#
# bad: TYL
#
#
#
#
#
#
#
#
# bad: DOW
#
# [*********************100%***********************]  1 of 1 completed
# bad: ADBE
#
# bad: EQIX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: HPE
#
#
# bad: YUM
#
#
#
# [*********************100%***********************]  1 of 1 completed
# bad: LRCX
#
# bad: SWKS
#
#
# bad: TRMB
# [*********************100%***********************]  1 of 1 completed
# bad: CE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
#
# [*********************100%***********************]  1 of 1 completed
#
# bad: DHI
#
# bad: WFC
#
# bad: MCK
#
# [*********************100%***********************]  1 of 1 completedbad: L
#
# bad: WAB
#
#
# bad: AMAT
#
# bad: FOX
# [*********************100%***********************]  1 of 1 completed
# bad: SEE
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: HWM
# [*********************100%***********************]  1 of 1 completed
# bad: BAC
#
# bad: STE
#
#
# bad: RMD
# [*********************100%***********************]  1 of 1 completed
# bad: FOXA
#
# [*********************100%***********************]  1 of 1 completed
# bad: DOV
#
# bad: FRC
#
#
# bad: DD
#
#
# bad: CTSH
#
# bad: BWA
#
#
# bad: UAA
#
# bad: NFLX
#
#
#
#
#
# bad: TSN
#
# bad: IBM
#
#
#
# bad: FDX
#
# bad: WELL
# [*********************100%***********************]  1 of 1 completed
#
#
# [*********************100%***********************]  1 of 1 completed
# bad: HES
# [*********************100%***********************]  1 of 1 completedbad: NDSN
# [*********************100%***********************]  1 of 1 completedbad: TFX
#
# bad: NWS
#
# bad: WMTbad: MRKbad: CZRbad: JBHT
#
# bad: VMC
# [*********************100%***********************]  1 of 1 completed
# bad: CHRW
#
# bad: FDS
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: TAP
#
# bad: BKR
#
# bad: CTRA
# bad: NWSA
#
# [*********************100%***********************]  1 of 1 completed
# bad: PTC
#
#
# bad: MSI
#
# bad: CL
# [*********************100%***********************]  1 of 1 completedbad: WY
# bad: CHD
# bad: PNW
# bad: FMCbad: PLDbad: MMC
#
# bad: PAYX
# bad: XELbad: HST
#
# bad: GL
# bad: FANG
# bad: SEDG
#
# bad: C
# bad: AJG
#
# bad: ABMD
#
# bad: PPG
#
# bad: GLW
#
# bad: TTbad: CVS
# bad: SO
#
#
# bad: RTX
#
# bad: MPWR
#
#
# [*********************100%***********************]  1 of 1 completed
# bad: ENPH
#
# bad: ODFL
#
#
# bad: GNRC
# bad: EW
# [*********************100%***********************]  1 of 1 completedbad: PHMbad: CAG
#
# [*********************100%***********************]  1 of 1 completedbad: FTNTbad: CEGbad: GS
# [*********************100%***********************]  1 of 1 completedbad: MHK
# bad: ALB
#
#
#
#
#
#
# bad: GOOGL
# bad: BA
#
# bad: MNST
#
#
# bad: RL
# bad: PG
# bad: CRM
#
#
# bad: DIS
# [*********************100%***********************]  1 of 1 completedbad: NVDA
#
# bad: AXP
#
# bad: ZBH
#
# bad: EMN
#
# bad: NUE
#
# [*********************100%***********************]  1 of 1 completed
# bad: TXT
#
#
# [*********************100%***********************]  1 of 1 completed
# bad: FB
#
# bad: ES
#
#
# bad: XRAY
#
#
# bad: ATO
# bad: MTD
# [*********************100%***********************]  1 of 1 completed
# bad: ADP
#
# bad: PFE
#
# [*********************100%***********************]  1 of 1 completed
#
# bad: TDG
# bad: STTbad: EPAM
#
#
# [*********************100%***********************]  1 of 1 completedbad: V
# bad: SNA
#
# [*********************100%***********************]  1 of 1 completed
#
# bad: JPM
#
# bad: RHI
# bad: UNP
#
# bad: CAH
#
# bad: EMR
#
#
# bad: NLOK
# bad: IRMbad: HAL
#
#
#
#
#
#
# bad: MMM
# bad: ANET
# bad: MOS
# [*********************100%***********************]  1 of 1 completedbad: CNC
# bad: PSA
#
# bad: EBAY
# bad: CHTRbad: ILMN
# bad: PNRbad: DAL
# [*********************100%***********************]  1 of 1 completed
# bad: ORLY
#
# bad: NEM
# bad: IPGP
#
#
# bad: AVGO
#
# bad: MCO
#
# bad: EL
#
#
# bad: UPS
#
#
#
# bad: ADI
# bad: LYV
#
# bad: AEE
# bad: CERN
# bad: PEAKbad: ICE
# bad: IEX
#
# [*********************100%***********************]  1 of 1 completedbad: BLL
# bad: LOW
#
# [*********************100%***********************]  1 of 1 completed
# bad: GIS
# bad: AES
# bad: NSC
#
# bad: BEN
#
# bad: BLK
#
# bad: KLAC
#
# bad: AAPL
#
#
#
# [*********************100%***********************]  1 of 1 completedbad: FISV
# bad: WSTbad: ALGNbad: AZO
# [*********************100%***********************]  1 of 1 completedbad: TXN
# bad: BSX
#
# bad: CMA
# bad: SNPS
#
#
# bad: F
# [*********************100%***********************]  1 of 1 completedbad: TWTR
#
#
# [*********************100%***********************]  1 of 1 completedbad: LNT
# bad: IT
#
#
#
#
# bad: TEL
#
#
#
# bad: CMI
#
# bad: FITBbad: SCHW
#
# bad: AKAM
#
# bad: GE
# [*********************100%***********************]  1 of 1 completedbad: BKNG
# bad: QCOM
# bad: BMYbad: TRV
#
# bad: BXPbad: DLTR
#
# [*********************100%***********************]  1 of 1 completed
# bad: TGT
#
# bad: LEN
# bad: SJM
# bad: FISbad: NOCbad: BR
# bad: EVRG
#
#
#
# [*********************100%***********************]  1 of 1 completed
# bad: TDY
# bad: DLR
#
#
#
#
#
# bad: DVA
#
#
# bad: WBAbad: ETRbad: FTV
# bad: ETSYbad: WMB
#
# bad: SLB
# bad: PWRbad: O
#
# bad: BIIB
#
# bad: TECH
# bad: MDLZ
#
#
# bad: CNP
#
#
# bad: PVH
# bad: HRL
# bad: BDX
# bad: KR
# bad: LIN
# bad: BBWI
#
#
# bad: CFGbad: AAP
# bad: WYNN
#
# bad: STZ
# bad: NCLH
# bad: RE
#
#
#
# bad: J
#
# bad: INCY
#
# bad: TPRbad: OTIS
#
# bad: IFF
# [*********************100%***********************]  1 of 1 completedbad: OGNbad: DISH
#
# bad: EFX
# bad: MGM
#
#
# bad: TMO
#
#
#
# bad: WRB
# bad: UHS
#
#
# bad: LLY
#
#
# bad: NI
#
#
# bad: NDAQbad: CMCSA
# bad: LUV
#
#
#
#
#
#
#
#
# bad: ZIONbad: HD
#
#
#
# bad: UDR
#
# bad: PXDbad: D
#
#
# bad: MTB
#
#
#
#
# bad: GILD
#
#
#
#
#
#
# bad: ED
#
#
#
#
#
#
#
#
#
#
# bad: MAR
#
# bad: HUM
#
# bad: LHX
# bad: SIVB
#
#
#
# bad: URI
#
#
# bad: COF
# bad: GRMN
#
# bad: CCI
#
# bad: MAA
#
#
#
#
# bad: TER
#
#
#
#
#
# bad: JCI
#
#
# bad: FE
#
#
#
#
#
#
#
#
# bad: ADSK
#
#
# bad: ROST
#
#
#
#
# bad: CB
#
#
# bad: GD
#
#
# bad: PPL
# bad: ABCbad: PARA
# bad: SPGIbad: AFLbad: VLO
# bad: MRO
# bad: BRK-Bbad: ALLbad: QRVO
# bad: AIG
# bad: K
# bad: RF
# bad: CCLbad: ETNbad: ACN
# bad: ARE
#
#
#
# bad: KMB
# bad: NWL
#
#
# bad: TMUS
# bad: CBREbad: SYY
# bad: HII
# bad: CMSbad: FASTbad: EXCbad: CTXSbad: UAL
# bad: NTAP
#
# bad: AMD
# bad: COObad: NEEbad: CPBbad: BK
# bad: OKE
#
# bad: GPNbad: RCL
# bad: JKHY
# bad: MET
#
#
#
#
#
#
# bad: IVZ
#
#
#
# bad: CPRT
# bad: ADM
#
# bad: AVYbad: PM
# bad: TTWO
#
#
#
#
#
# bad: MRNA
#
#
#
#
#
#
#
# bad: KMI
#
#
#
# bad: MSCIbad: CINF
# bad: PH
#
#
#
# bad: ABT
#
#
# bad: ISRG
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-03-23   18.500000   19.610001   18.120001   19.469999   18.383108
# 2004-03-24   19.330000   19.500000   18.969999   19.450001   18.364225
# 2004-03-25   19.350000   19.440001   19.100000   19.350000   18.269806
# 2004-03-26   19.450001   19.450001   19.150000   19.389999   18.307571
# 2004-03-29   19.200001   19.600000   19.200001   19.240000   18.165947
# ...                ...         ...         ...         ...         ...
# 2022-04-26  257.959991  259.369995  247.660004  247.809998  247.809998
# 2022-04-27  247.809998  252.419998  245.729996  247.490005  247.490005
# 2022-04-28  251.339996  252.839996  242.449997  251.539993  251.539993
# 2022-04-29  251.479996  254.429993  240.789993  242.250000  242.250000
# 2022-05-02  245.029999  249.210007  239.899994  248.630005  248.630005
#
#              Volume
# Date
# 2004-03-23  5282200
# 2004-03-24   505000
# 2004-03-25   209700
# 2004-03-26   293200
# 2004-03-29   153600
# ...             ...
# 2022-04-26   652100
# 2022-04-27   500900
# 2022-04-28   656700
# 2022-04-29   776300
# 2022-05-02   717400
#
# [4560 rows x 6 columns]
#
#
#
# bad: BRO
#
# bad: EIX
#
# bad: KEYbad: HSICbad: HBAN
#
# bad: AMPbad: EQR
#
#
# bad: NXPI
#
# bad: DFS
# bad: GM
# bad: MKTX
#
#
#
#
# bad: CPT
# bad: ITW
#
#
#
#
#
#
#
#
#
# bad: MTCH
# bad: EXR
# bad: ECL
#
# bad: VNO
#
# bad: HPQ
# bad: CARR
# bad: BAX
# bad: BF-B
# bad: DRE
# bad: CTAS
#
#
#
# bad: CDAY
# bad: IP                  Open        High         Low       Close   Adj Close  \
# Date
# 2006-10-17   44.617283   44.641975   43.604939   44.370369   23.546116
# 2006-10-18   45.037037   45.037037   43.432098   43.629631   23.153027
# 2006-10-19   43.629631   43.925926   42.493828   42.641975   22.628906
# 2006-10-20   42.962963   44.197533   42.592594   44.074074   23.388885
# 2006-10-23   44.691357   44.691357   43.580246   43.925926   23.310261
# ...                ...         ...         ...         ...         ...
# 2022-04-26  107.190002  108.790001  106.589996  106.629997  106.629997
# 2022-04-27  106.720001  107.389999  105.559998  106.239998  106.239998
# 2022-04-28  106.589996  106.589996  104.349998  105.029999  105.029999
# 2022-04-29  104.849998  105.730003  103.160004  103.510002  103.510002
# 2022-05-02  103.379997  105.250000  102.779999  103.510002  103.510002
#
#              Volume
# Date
# 2006-10-17  1741338
# 2006-10-18  1484487
# 2006-10-19  1481774
# 2006-10-20  1440342
# 2006-10-23  1152306
# ...             ...
# 2022-04-26   690600
# 2022-04-27   686700
# 2022-04-28  1047100
# 2022-04-29  1318500
# 2022-05-02  1087000
#
# [3912 rows x 6 columns]
# bad: DHR
#
# bad: MAS
#
#
#
# bad: WEC
#
# bad: EXPD
#
# bad: NKE
#
# bad: MLM
#
# bad: WM
#
#
#
#
#
#
#
# bad: APH
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: SBAC
#
#
#
# bad: TJX
# bad: DUKbad: REG
#
# bad: CDWbad: UAbad: AIZbad: APTVbad: LWbad: OMC
# bad: XYLbad: MA
#
# bad: XOM
#
#
# bad: CVXbad: STXbad: VFC
# bad: HASbad: PGR
#
# bad: WRK
# bad: AMZN
#
# bad: VRTX
#
# bad: WTW
# bad: COSTbad: HCA
# bad: LMT
#
# bad: MCHPbad: IQVbad: KMX
#
#
#
#
# bad: LH
#
#
#
# bad: SBUX
#
# bad: MCDbad: LUMN
#
#
#
# bad: CATbad: AOSbad: AME
#
#
#
#
#
#
# bad: ROP
#
#
# bad: NOWbad: ANTM
#
#
#
#
# bad: MU
#
# bad: SPG
#
# bad: IDXX
#
#
# bad: EXPE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: ZBRA
# bad: MObad: PEPbad: KHCbad: VTRSbad: PRUbad: DTE
#
# bad: MOH
#
#
#
#
#
# bad: LNC
#
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-28   22.250000   22.250000   21.700001   22.000000    9.909109
# 2010-04-29   22.000000   23.250000   21.900000   23.000000   10.359527
# 2010-04-30   22.950001   23.000000   22.250000   22.299999   10.044231
# 2010-05-03   22.750000   22.950001   22.650000   22.799999   10.269442
# 2010-05-04   22.799999   22.799999   21.500000   21.500000    9.683903
# ...                ...         ...         ...         ...         ...
# 2022-04-26  105.209999  106.410004  104.199997  104.260002  104.260002
# 2022-04-27  105.680000  106.639999  104.360001  105.320000  105.320000
# 2022-04-28  106.099998  106.809998  104.250000  106.099998  106.099998
# 2022-04-29  109.070000  110.940002  105.809998  106.029999  106.029999
# 2022-05-02  108.800003  109.199997  105.889999  108.010002  108.010002
#
#              Volume
# Date
# 2010-04-28  5244400
# 2010-04-29  8773600
# 2010-04-30  1644400
# 2010-05-03  3302700
# 2010-05-04  2276500
# ...             ...
# 2022-04-26  1265100
# 2022-04-27  1658300
# 2022-04-28  2465900
# 2022-04-29  2268900
# 2022-05-02  3071500
#
# [3025 rows x 6 columns]
#
# bad: AONbad: DXCMbad: RJFbad: ROL
#
# bad: AAL
# bad: PKIbad: Tbad: INTCbad: JNPRbad: HSY
# bad: COP
#
# bad: CRLbad: DVN
# bad: USB
#
# bad: KIM
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: APD
# bad: APA
#
#
#
# bad: AMT
# bad: DPZbad: NRGbad: EAbad: ALKbad: AMGNbad: CTVAbad: NVR
#
#
#
#
#
#
#
# bad: MS
#
#
#
#
# bad: AEP
#
#
#
# bad: WAT
#
#
# bad: WHR
#
# bad: ANSS
#
#
# bad: SWKbad: HOLX
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
# bad: WMT
#
#
# bad: CSCO
#
# bad: SEE
# bad: XRAY
#
# bad: ALB
#
# bad: MCD
#
# bad: GL
#
#
#
# bad: PEAK
# bad: ADI
# bad: LDOS
#
# bad: EOGbad: BSX
#
# bad: TRV
# bad: LYB
#
# bad: D
# bad: ETSY
# bad: XELbad: LYV
# bad: ROSTbad: FMC
# bad: SBNYbad: LIN
# bad: ES
# bad: ADMbad: MNST
# bad: EMR
#
#
#
#
#
#
#
#
#
# bad: EXR
#
# [*********************100%***********************]  1 of 1 completed
# bad: WRB
# [*********************100%***********************]  1 of 1 completed
# bad: AXP
#
# bad: PWR
#
# bad: MTD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# bad: CMI
#
# [*********************100%***********************]  1 of 1 completed
# bad: KIM
#
# bad: AAP
#
# [*********************100%***********************]  1 of 1 completed
# bad: NLOK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# bad: BLK
#
# bad: BBY
# [*********************100%***********************]  1 of 1 completedbad: DUK
#
#
# bad: QRVO
#
# bad: A
#
# bad: MOS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# bad: VZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# bad: DFS
#
# bad: PARA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completedbad: LH
# bad: ATVI
# [*********************100%***********************]  1 of 1 completedbad: AIG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# bad: TPR
# [*********************100%***********************]  1 of 1 completed
# bad: AZO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completedbad: LNT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# bad: AMT
# [*********************100%***********************]  1 of 1 completed
# bad: WST
# [*********************100%***********************]  1 of 1 completedbad: EPAM
#
# bad: JNPR
#
# bad: FISV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# bad: TYL
# [*********************100%***********************]  1 of 1 completedbad: METbad: NFLX
# [*********************100%***********************]  1 of 1 completed
# bad: WELL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completedbad: BACbad: BKR
# [*********************100%***********************]  1 of 1 completed
# bad: HD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completedbad: TSN
# [*********************100%***********************]  1 of 1 completedbad: FRC
# bad: EA
# [*********************100%***********************]  1 of 1 completed
# bad: AON
# [*********************100%***********************]  1 of 1 completed
#
# bad: MRO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completedbad: ROL
# [*********************100%***********************]  1 of 1 completedbad: AME
# bad: PEG
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# bad: GLW
# [*********************100%***********************]  1 of 1 completedbad: COP
# [*********************100%***********************]  1 of 1 completed
# bad: NTAP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completedbad: RE
# [*********************100%***********************]  1 of 1 completedbad: WATbad: PKG
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
# bad: TDY
# [*********************100%***********************]  1 of 1 completed
#
# bad: PNW
# [*********************100%***********************]  1 of 1 completedbad: SBUX
# [*********************100%***********************]  1 of 1 completed
# bad: CZR
# [*********************100%***********************]  1 of 1 completed
#
# bad: AMGN
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completedbad: INTC
# [*********************100%***********************]  1 of 1 completed
#
# bad: CCI
#
# bad: APTV
#
#
#
#
#
#
# bad: NTRS
#
# bad: K
#
#
# bad: CPRT
#
#
#
#
# bad: ZBH
#
#
#
# bad: BF-B
#
#
# bad: DIS
#
# bad: AVY
#
#
#
# bad: CL
# bad: CTAS
#
#
# bad: MAS
# bad: NVR
# bad: CME
# bad: PMbad: STZ
#
# bad: MObad: PGR
#
# bad: CE
#
#
# bad: AMDbad: GSbad: CRLbad: WTWbad: AMZN
# bad: DPZ
#
#
#
# bad: BEN
# bad: MOH
#
# bad: PPG
#
# bad: MKTX
#
# bad: TEL
#
# bad: AEE
#
# bad: DOW
# bad: REGN
# bad: SPG
#
# bad: BIO
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1992-02-26    7.125000    8.250000    6.875000    7.875000    7.875000
# 1992-02-27    8.062500    8.062500    7.687500    7.781250    7.781250
# 1992-02-28    7.812500    7.937500    7.562500    7.687500    7.687500
# 1992-03-02    7.625000    8.062500    7.562500    7.937500    7.937500
# 1992-03-03    7.937500    8.062500    7.875000    8.000000    8.000000
# ...                ...         ...         ...         ...         ...
# 2022-04-26  290.920013  292.940002  281.299988  282.899994  282.899994
# 2022-04-27  283.000000  293.829987  283.000000  287.029999  287.029999
# 2022-04-28  291.950012  305.059998  290.709991  301.859985  301.859985
# 2022-04-29  298.549988  302.369995  285.540009  286.790009  286.790009
# 2022-05-02  286.549988  291.230011  280.899994  290.709991  290.709991
#
#               Volume
# Date
# 1992-02-26  11616800
# 1992-02-27   1918400
# 1992-02-28   1387200
# 1992-03-02   1206000
# 1992-03-03    222800
# ...              ...
# 2022-04-26   1022200
# 2022-04-27   1005400
# 2022-04-28    724100
# 2022-04-29    763100
# 2022-05-02   1028900
#
# [7603 rows x 6 columns]
#
# bad: EQIX
#
#
# bad: CBRE
#
#
#
#
# bad: NCLH
#
#
# bad: BK
#
#
#
#
# bad: FRT
#
#
#
#
#
# bad: BRO
# bad: HPE
#
# bad: EBAY
#
#
#
# bad: IP
#
# bad: DOV
# bad: CFGbad: VFC
#
# bad: ALL
# bad: AJGbad: NI
# bad: CB
# bad: AMPbad: DGXbad: CHTR
# bad: TGT
# bad: TMO
# bad: PNRbad: CPB
#
#
#
# bad: PPL
#
#
# bad: C
#
#
#
#
#
#
#
#
#
#
# bad: APD
#
#
#
#
#
#
# bad: SJM
# bad: CEGbad: ANTM
# bad: CMS
#
#
#
# bad: SIVBbad: EL
# bad: ZION
# bad: GOOGLbad: ORLY
#
#
# bad: BKNG
# bad: BLL
#
#
# bad: LW
#
# bad: WRKbad: IVZ
#
#
#
# bad: MMMbad: XOMbad: UHS
# bad: COFbad: RTX
#
# bad: WBA
# bad: EMNbad: STX
#
#
#
#
# bad: SBAC
#
#
#
# bad: CTXS
#
#
#
#
# bad: WAB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: TRMB
#
#
#
#
#
#
#
# bad: FIS
#
# bad: MTB
# bad: MAAbad: MCHPbad: UPSbad: KRbad: VNO
# bad: KMB
# bad: MCK
# bad: PHMbad: CTRAbad: HONbad: MSCIbad: LRCX
#
#
# bad: GISbad: EWbad: IPG
# bad: CERNbad: DXCMbad: OGNbad: BA
#
#
#
#
# bad: UA
# bad: KMX
#
#
#
# bad: VMC
# bad: AVGO
#
# bad: SEDG
#
#
#
#
#
# bad: PRU
#
# bad: IEX
# bad: GE
#
# bad: IRM
# bad: ABMDbad: HESbad: EDbad: TSLA
#
# bad: NOC
#
#
#
#
# bad: PEP
#
#
#
#
#
#
#
# bad: ABTbad: APH
#
#
#
#
# bad: SYF
#
#
#
# bad: PSA
#
#
#
# bad: PTC
# bad: FOX
#
# bad: AAPL
#
#
#
#
# bad: GNRC
# bad: ADPbad: APA
# bad: TWTRbad: HAL
# bad: ICE
#
# bad: FDS
#
# bad: PLD
#
# bad: L
#
#
# bad: MA
# bad: KEY
#
# bad: QCOM
#
#
# bad: HAS
#
# bad: WMB
#
#
#
#
# bad: SO
#
# bad: ZBRA
# bad: NXPIbad: LHXbad: UAL
# bad: VRTX
# bad: DHR
#
#
# bad: JBHT
#
#
#
#
# bad: EXPE
# bad: HUM
#
# bad: RF
#
# bad: BMY
#
# bad: AKAM
#
# bad: VLO
#
#
# bad: SYY
#
# bad: SLB
#
# bad: NOW
#
# bad: MLM
#
# bad: DVA
#
# bad: CLX
#
# bad: FFIV
#
# bad: BDX
#
#
# bad: DAL
#
#
# bad: TAP
#
# bad: KHC
#
#
#
#
#
# bad: BIIB
#
# bad: UDR
#
# bad: LUV
#
# bad: NLSN
#
#
#
#
# bad: NDAQ
#
#
# bad: STE
#
#
#
# bad: WM
#
#
#
#
#
#
#
#
#
#
#
# bad: J
# bad: ROP
#
# bad: STT
# bad: CTVA
#
# bad: O
#
#
#
#
#
#
#
#
#
#
# bad: DLR
#
#
#
#
#
#
#
# bad: FOXA
#
# bad: HPQ
#
# bad: COO
#
# bad: FITB
#
#
# bad: RSG
#
#
#
#
#
# bad: OTIS
#
# bad: NWL
#
# bad: UAA
# bad: TTbad: RL
#
# bad: XYL
#
#
#
#
#
# bad: ACN
# bad: ALK
#
#
# bad: IRbad: TXN
# bad: EIX
# bad: UNP
# bad: ETNbad: AALbad: T
# bad: ITW
# bad: DLTR
#
#
#
# bad: VTRSbad: LNC
#
#
#
#
#
# bad: JKHY
# bad: TMUSbad: AMAT
# bad: LOW
#
#
# bad: CVSbad: CINFbad: IDXXbad: MHKbad: CTSH
#
# bad: ETR
#
#
#
#
#
#
#
#
# bad: MMC
#
# bad: AIZ
#
# bad: ABCbad: CNPbad: BRK-Bbad: F
#
#
# bad: NWSbad: RHIbad: ODFL
# bad: OKEbad: CRM
# bad: PH
#
# bad: CVX
# bad: NWSAbad: CARR
#
#
# bad: IFF
#
#
# bad: NVDAbad: WHRbad: AFL
#
# bad: CPTbad: EXPD
# bad: BWAbad: NEMbad: MRNA
#
# bad: ANETbad: MTCHbad: ANSSbad: EXC
# bad: CHRWbad: NEE
# bad: FTNT
# bad: AOS
#
#
#
#
# bad: REG
# bad: HSICbad: CNC
# bad: HSY
#
# bad: NSC
#
#
#
#
#
#
#
# bad: GILDbad: GPN
#
# bad: MCObad: CAH
# bad: ALGNbad: ENPH
#
#
# bad: UNH
# bad: OMC
# bad: CMA
#
# bad: GRMN
# bad: GD
# bad: SNA
# bad: RMD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: DISH
# bad: WYNN
#
#
# bad: FB
#
#
# bad: DHI
#
# bad: WFC
#
# bad: LMT
#
#
#
# bad: SPGI
# bad: JCI
#
#
# bad: KEYS
#
#
#
#
# bad: DRE
#
# bad: BAX
#
#
# bad: CCL
# bad: HII
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: MRK
#
#
#
# bad: TECH
#
#
#
#
#
#
# bad: MGM
#
#
#
#
#
#
#
#
#
# bad: CAG
# bad: DD
# bad: ECL
#
# bad: CAT
# bad: WY
# bad: PAYX
# bad: HST
# bad: TFXbad: MS
#
#
#
# bad: ILMN
#
# bad: COST
#
#
# bad: MSIbad: CDNS
# bad: SWKS
# bad: LENbad: ISRG
# bad: TXT
# bad: NKEbad: HBAN
# bad: MUbad: LUMN
# bad: PVH
# bad: RCL
#
#
#
#
#
# bad: SYK
# bad: MDLZ
# bad: EQR
#
#
# bad: AEP
# bad: EFX
# bad: TTWO
# bad: BXP
#
# bad: BBWI
#
# bad: PXD
#
# bad: FDX
#
#
# bad: FASTbad: PKI
#
#
#
# bad: NDSNbad: NUE
# bad: BR
#
#
# bad: FEbad: V
# bad: HRL
# bad: PG
#
# bad: ADSKbad: HWM
# bad: FANGbad: TER
# bad: AES
# bad: TDGbad: DTEbad: RJF
# bad: AREbad: EVRGbad: DVNbad: CMCSA
# bad: MPWR
#
# bad: ADBEbad: URI
# bad: CDAY
# bad: KMI
# bad: LLY
# bad: HOLX
#
# bad: USB
#
# bad: MDT
#
# bad: SCHW
#
#
# bad: NRG
#
# bad: YUM
#
# bad: INCYbad: TFC
#
#
#
#
#
# bad: KLAC
# bad: GM
#
# bad: MAR
# bad: IPGP
#
#
# bad: FCX
#
#
# bad: SWK
# bad: CHD
#
#
#
# bad: HLT
#
# bad: FTV
#
#
# bad: IQVbad: WEC
#
#
#
#
# bad: JPMbad: IT
#
#
# bad: TJX
#
#
# bad: ATO
#
# bad: LVS
# bad: IBM
#
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
# bad: MCD
#
#
#
#
#
#
#
#
#
# bad: ISRG
#
#
#
# bad: PM
#
# bad: CL
#
# bad: MNST
#
#
#
# bad: WBAbad: SWKbad: OMCbad: NEM
# bad: ADI
#
# bad: CINF
# bad: BRObad: GRMNbad: CSCO
# bad: CMCSAbad: TDY
#
# bad: TAP
#
#
#
#
# bad: ROSTbad: WST
# bad: GL
#
# bad: VTRS
# bad: NTAP
# bad: TPR
#
# bad: EW
#
#
#
# bad: FTVbad: HBAN
#
# bad: PPG
#
# bad: ABT
#
# bad: ETN
# bad: PTCbad: OGN
# bad: MPWR
#
# bad: UPS
# bad: CEG
# bad: XELbad: MSbad: APA
#
# bad: TRV
# bad: ENPHbad: AZO
#
#
# bad: AES
#
#
#
#
#
#
#
#
# bad: NRG
#
#
#
#
#
#
# bad: D
#
# bad: CNC
#
# bad: RSG
#
#
#
#
#
# bad: ADM
#
#
# bad: MTD
# bad: CTAS
#
# bad: BK
# bad: HAS
# bad: DUKbad: IFF
# bad: AAPLbad: TJXbad: EBAY
#
#
#
#
# bad: KMB
#
#
# bad: CVX
#
#
# bad: OKE
#
#
#
#
#
#
#
# bad: AMD
#
# bad: ES
# bad: MAbad: BAX
# bad: NWL
# bad: KMX
#
# bad: HD
# bad: HUM
#
# bad: NWSA
#
# bad: FMCbad: ZIONbad: QRVO
#
# bad: INTC
#
# bad: NSC
#
#
# bad: LYB
#
#
# bad: EQR
#
# bad: LLY
#
#
#
# bad: CPB
#
# bad: FCX
# bad: EOG
#
#
# bad: PNR
#
#
#
# bad: HOLX
#
#
# bad: IT
#
#
#
#
#
# bad: CERN
#
# bad: RL
#
#
# bad: FDX
#
#
#
# bad: PFE
#
# bad: F
#
# bad: EMR
#
#
#
# bad: MOH
# bad: BLK
#
# bad: NWS
#
#
# bad: AMP
# bad: CAG
# bad: HON
# bad: IR
# bad: MTB
#
#
# bad: SYK
# bad: FOXA
#
# bad: URI
# bad: ACN
# bad: PEAK
#
#
#
#
# bad: LNT
#
# bad: ETR
#
# bad: NKE
#
# bad: WEC
#
#
# bad: IPG
#
#
# bad: LVS
#
# bad: FITB
# bad: CTRA
#
# bad: EQIX
# bad: MRO
#
#
# bad: FTNT
#
# bad: CTSH
#
# bad: COST
#
#
#
#
# bad: CCL
#
#
# bad: ADP
#
#
# bad: GS
#
#
# bad: STZ
#
#
# bad: VFC
#
# bad: COP
#
#
# bad: SEDG
# bad: IQV
#
# bad: CTXS
#
#
#
# bad: PVH
#
#
#
#
# bad: MAS
#
# bad: EXPD
#
#
#
#
#
# bad: PHM
#
#
#
#
#
#
#
# bad: CMS
# bad: WRB
#
# bad: ODFL
#
# bad: TER
# bad: PEP
#
# bad: PG
#
# bad: WMT
# bad: NDSN
# bad: SEE
#
#
# bad: LYV
#
# bad: PLD
# bad: PAYX
#
#
# bad: WAT
# bad: EXPE
# bad: APTV
#
#
#
#
#
#
# bad: HLT
# bad: ECL
#
#
#
#
# bad: ALB
# bad: AEPbad: SBNY
# bad: MMM
#
# bad: MGM
# bad: AMGN
# bad: TFC
#
# bad: CRL
# bad: JCI
# bad: AALbad: CFG
#
# bad: TYL
#
# bad: TEL
#
# bad: PPL
# bad: WYNN
#
# bad: KMI
# bad: WTWbad: TTWO
#
# bad: RTX
# bad: JNPRbad: SPGIbad: LIN
#
# bad: CDW
#
# bad: INCY
#
# bad: A
# bad: SNPS
#
#
# bad: ANET
#
# bad: JPM
# bad: UALbad: DOV
#
# bad: XYL
#
# bad: HSIC
# bad: V
# bad: BSX
# bad: KEY
#
# bad: EPAM
# bad: XRAY
#
# bad: DTE
#
# bad: AKAM
# bad: CME
# bad: KLAC
# bad: LUVbad: IVZ
# bad: DAL
#
# bad: KEYS
#
# bad: VZ
# bad: CZR
#
#
#
#
#
# bad: DFS
# bad: MDT
# bad: GIS
#
# bad: MAR
#
# bad: WELL
# bad: LW
#
#
#
# bad: MCO
# bad: ATVIbad: CARR
#
# bad: BBY
#
#
# bad: BMY
#
#
# bad: ROP
#
# bad: PKI
#
#
#
#
# bad: EIX
# bad: DLR
#
# bad: MDLZ
# bad: NLSN
#
# bad: ILMN
#
#
#
#
#
# bad: BKNGbad: TGT
# bad: ARE
#
# bad: NTRS
# bad: ABMDbad: HWMbad: FAST
# bad: NDAQ
#
# bad: UNP
# bad: HPE
# bad: DD
# bad: HRL
#
# bad: LDOS
# bad: BIO
#
# bad: SBUX
#
# bad: TFX
# bad: NEE
# bad: GNRC
# bad: WY
# bad: SObad: HST
#
#
#
#
# bad: DREbad: FB
# bad: CHRW
# bad: ETSY
#
#
# bad: ITW
#
#
#
#
#
#
#
#
#
# bad: WFC
#
# bad: AAP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completedbad: CAH
# [*********************100%***********************]  1 of 1 completed
#
# bad: CPRT
#
#
# bad: UHS
#
#
#
#
#
#
#
#
# bad: MCHP
#
#
#
#
# bad: SYY
#
#
# bad: REGN
#
#
#
#
#
#
#
#
# bad: BF-B
#
#
#
#
#
#
# bad: CHD
#
#
#
# bad: TWTR
#
#
#
# bad: CLX
#
#
#
#
#
#
# bad: MSI
#
# bad: BAC
#
#
#
#
#
# bad: ANTM
#
#
# bad: EXR
#
#
#
#
#
# bad: CRM
#
#
# bad: NVR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: GM
#
#
#
#
#
#
#
#
#
#
# bad: JBHT
#
#
#
#
#
#
#
#
#
#
#
#
# bad: XOM
#
#
# bad: DHI
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: STT
#
# bad: NXPI
#
#
#
#
#
# bad: HII
#
#
#
#
#
#
#
#
#
#
#
#
# bad: HPQ
#
#
# bad: AMATbad: EAbad: LHXbad: BA
# bad: TMO
#
#
# bad: DIS
# bad: ORLY
# bad: DXCM
#
#
# bad: C
#
# bad: DVNbad: AONbad: LOWbad: NVDAbad: GILDbad: PARAbad: YUM
#
#
# bad: BKRbad: PKGbad: GPNbad: ROLbad: BBWI
#
# bad: NIbad: TT
#
# bad: IRMbad: SPG
#
#
# bad: ALGNbad: BEN
# bad: WMB
#
#
# bad: DLTR
# bad: MOSbad: NUEbad: VLO
#
#
# bad: ZBH
#
#
#
# bad: MRKbad: Tbad: IBMbad: TRMB
#
# bad: MMC
#
#
# bad: QCOMbad: ATObad: CVSbad: DOWbad: AEEbad: NLOKbad: AVGObad: AVYbad: EMNbad: FRCbad: WMbad: METbad: FE
# bad: NCLH
# bad: IPGP
# bad: GE
# bad: MHKbad: WRKbad: Jbad: EXCbad: AIZ
#
#
# bad: Kbad: REGbad: IEXbad: AIGbad: LENbad: DVAbad: JKHYbad: PNWbad: BXPbad: TECHbad: VNO
#
#
#
# bad: MLM
# bad: SJMbad: VMCbad: HALbad: ABCbad: HESbad: UAAbad: FOXbad: PEGbad: MCKbad: APDbad: FRTbad: CBbad: FANGbad: CHTRbad: RF
#
# bad: FDS
#
# bad: SBACbad: SLBbad: TMUSbad: RMD
#
# bad: MRNA
# bad: DISHbad: FISVbad: REbad: TDGbad: KR
# bad: WHR
# bad: AXPbad: CMA
# bad: ALK
#
#
# bad: PRUbad: DGX
# bad: CBREbad: CDNSbad: CPT
#
#
# bad: PWRbad: MAAbad: FFIV
#
# bad: CE
#
#
#
#
#
# bad: PSAbad: GLWbad: GOOGL
#
#
#
# bad: EFXbad: ANSS
#
# bad: BWAbad: RJF
#
# bad: AMTbad: LNCbad: TXT
# bad: NOCbad: DPZ
# bad: BIIBbad: CMI
#
#
#
#
# bad: NOW
# bad: UNH
#
# bad: TSLAbad: PH
#
#
#
# bad: AJGbad: DHR
# bad: ELbad: RCLbad: ZBRA
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: APH
#
# bad: USBbad: TSN
#
#
#
# bad: SCHWbad: LUMN
#
#
#
#
#
#
#
# bad: IDXX
# bad: ALLbad: AOSbad: ADBEbad: AFLbad: CCIbad: IP
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: STE
#
#
# bad: LRCX
#
#
#
# bad: COFbad: EVRG
#
#
#
# bad: Obad: PXD
#
# bad: CATbad: MU
#
#
#
#
# bad: VRTXbad: CNP
#
#
# bad: SNAbad: AME
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: SYFbad: SWKSbad: OTIS
# bad: BR
# bad: MSCIbad: FIS
# bad: MTCHbad: BDX
#
#
#
#
#
# bad: MKTXbad: KIM
# bad: TXN
#
#
#
# bad: PGR
#
#
#
#
# bad: SIVB
#
#
#
#
#
# bad: UA
# bad: EDbad: KHCbad: UDR
# bad: L
#
#
#
# bad: HSY
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: HCA
# bad: BRK-B
#
#
#
#
# bad: CDAY
#
#
# bad: GD
#
# bad: LMT
#
#
# bad: CTVA
#
# bad: LHbad: MO
# bad: ADSK
# bad: BLL
# bad: WAB
# bad: STX
#
#
# bad: ICEbad: NFLX
# bad: RHI
#
# bad: AMZNbad: COO
#
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# bad: HLT
# bad: HPE
# bad: NTRS
#
# bad: ETR
#
#
# bad: EPAM
#
# bad: CHRW
#
# bad: CARR
#
#
# bad: AAP
#
# bad: PNR
#
# bad: UNP
#
# bad: MOH
#
# bad: SEDG
#
#
# bad: DD
# bad: HON
#
# bad: EMR
#
# bad: SNPS
#
# bad: CTRA
#
# bad: AMD
# bad: NKE
#
#
#
# bad: GL
#
#
# bad: BBY
# bad: CVX
#
#
# bad: EXR
# bad: NLSNbad: SPG
# bad: MA
#
# bad: XRAY
#
#
# bad: ECL
#
# bad: NTAP
#
# bad: LLY
#
#
#
#
#
# bad: RSG
#
#
#
#
# bad: VFC
#
# bad: SEE
#
#
#
# bad: JCI
# bad: MDLZ
#
# bad: DLR
#
#
#
#
#
#
# bad: ETSY
# bad: URIbad: CZRbad: CCLbad: FITB
#
# bad: NEE
# bad: ZION
# bad: EW
# bad: CMEbad: TAPbad: DUKbad: ENPHbad: PM
#
# bad: ROP
# bad: DISbad: HAS
#
#
#
#
#
# bad: MTB
#
#
#
#
#
# bad: HBANbad: EQIX
#
#
#
# bad: BSX
#
# bad: ADP
#
#
#
#
# bad: GRMN
#
# bad: AES
# bad: WATbad: IPG
#
#
#
# bad: ADM
#
# bad: WST
# bad: EXPD
#
# bad: APTV
#
# bad: XYLbad: WBA
# bad: UPS
#
# bad: KEY
#
#
#
# bad: PKIbad: PHM
#
#
# [*********************100%***********************]  1 of 1 completed
# bad: BIIB
# [*********************100%***********************]  1 of 1 completed
# bad: TDY
#
# [*********************100%***********************]  1 of 1 completed
# bad: NOW
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# bad: LEN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completedbad: CDWbad: PKG
# [*********************100%***********************]  1 of 1 completedbad: SCHW
# [*********************100%***********************]  1 of 1 completedbad: YUMH
# [*********************100%***********************]  1 of 1 completedbad: CAG
# bad: STZ
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completedbad: ORLYLbad: EXCbad: SLB
# [*********************100%***********************]  1 of 1 completedbad: DISHbad: GEbad: BBWI
#
# [*********************100%***********************]  1 of 1 completedbad: STT
#
# [*********************100%***********************]  1 of 1 completedbad: LOWbad: O
# [*********************100%***********************]  1 of 1 completedbad: NDAQ
# [*********************100%***********************]  1 of 1 completedbad: FDSad: ADI
# [*********************100%***********************]  1 of 1 completedbad: NFLX
# [*********************100%***********************]  1 of 1 completedbad: ANET
# bad: HCA
#
#
# bad: JBHTbad: IFF
#
# [*********************100%***********************]  1 of 1 completedbad: HOLX
# [*********************100%***********************]  1 of 1 completedbad: APH
# [*********************100%***********************]  1 of 1 completedbad: WECbad: TMUSbad: INTC
# [*********************100%***********************]  1 of 1 completedbad: KLAC
#
# [*********************100%***********************]  1 of 1 completedbad: NVRbad: FFIVbad: SJM
# bad: PNW
#
# bad: PEP
#
#
#
#
# bad: AXP
# bad: ALL
# [*********************100%***********************]  1 of 1 completedbad: LVSbad: AIG
#
#
#
# [*********************100%***********************]  1 of 1 completedbad: TERbad: NRG
#
# bad: MS
# bad: OMC
# bad: FANG
#
#
#
# bad: FRTbad: PTC
# bad: SBUX
#
# bad: EFX
#
# bad: ADSK
#
#
#
#
# bad: TT
#
# bad: CMCSA
# [*********************100%***********************]  1 of 1 completedbad: MGM
#
#
#
# bad: EL
# bad: MAAbad: HD
#
#
#
#
# bad: FCX
# bad: PFE
# bad: TDG
#
# bad: AMZN
#
# bad: EVRGbad: WRKbad: SIVBbad: UDRbad: DHIbad: EOG
#
# bad: LH
#
# bad: SYK
#
#
#
#
#
#
# bad: MMM
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: NWS
# bad: EA
#
#
# bad: CAHbad: AVYbad: LUV
# bad: CTXS
# bad: AVGObad: ROLbad: BWAbad: Fbad: TSN                 Open       High        Low      Close  Adj Close     Volume
# Date
# 1980-03-17   0.000000  10.400000   9.966667  10.266667   6.091917   519375.0
# 1980-03-18   0.000000  10.533333   9.500000  10.533333   6.250151   659250.0
# 1980-03-19   0.000000  10.833333  10.333333  10.766667   6.388607   408000.0
# 1980-03-20   0.000000  11.000000  10.566667  10.800000   6.408383   607125.0
# 1980-03-21   0.000000  10.833333  10.333333  10.666667   6.329272   229125.0
# ...               ...        ...        ...        ...        ...        ...
# 2022-04-26  73.029999  73.940002  72.120003  72.129997  72.129997  5167000.0
# 2022-04-27  72.610001  73.690002  71.959999  72.129997  72.129997  5416300.0
# 2022-04-28  72.779999  73.660004  72.010002  73.279999  73.279999  3913500.0
# 2022-04-29  74.110001  74.989998  72.739998  72.849998  72.849998  5680700.0
# 2022-05-02  71.199997  72.629997  70.349998  72.309998  72.309998  5837600.0
#
# [10624 rows x 6 columns]bad: HSIC
# bad: TXT
# bad: CPB
# bad: IEX
# bad: WYNN
#
# bad: CNC
#
#
# bad: DXCMbad: C
# bad: FBbad: AMP
#
# bad: JKHY
#
# bad: SWKS
# bad: RTX
#
#
#
#
#
# bad: VTRS
#
# bad: MCHP
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: IP
#
#
#
# bad: FIS
#
#
#
#
#
#
#
#
# bad: OKE
#
# bad: ETN
#
#
#
#
#
#
#
#
# bad: DAL
#
#
#
# bad: VLObad: TTWObad: TELbad: BLL
# bad: BMYbad: ABTbad: MObad: MLMbad: FAST
#
# bad: ISRGbad: APDbad: WRB
#
# bad: A
# bad: COObad: GD
# bad: AREbad: Kbad: COF
# bad: MDT
#
# bad: DVAbad: FDX
# bad: TGTbad: COSTbad: ATVI
#
#
# bad: PEAKbad: PPLbad: TSLA
# bad: CSCO
#
# bad: MCDbad: PG
#
#
#
#
#
#
# bad: IRbad: CPRT
# bad: CEG
#
#
#
# bad: NOCbad: HWM
#
# bad: TRV
#
# bad: LYVbad: FMCbad: TJX
#
#
#
#
#
#
# bad: AEE
# bad: ABMD
#
#
#
#
# bad: PLD
#
#
# bad: IDXXbad: LYB
#
#
#
#
#
# bad: KEYS
#
#
# bad: PAYX
#
#
#
#
#
#
#
# bad: MCO
#
#
# bad: UAA
# bad: MAR
# bad: AMT
#
#
#
#
# bad: WMT
#
#
# bad: GNRC
# bad: HAL
#
#
#
# bad: EBAY
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: SBNY
# bad: BAX
#
# bad: SWK
#
#
# bad: PARA
#
# bad: CTAS
# bad: CLX
# bad: DTE
# bad: STX
# bad: GILD
# bad: CBREbad: PRUbad: FTVbad: IBMbad: BACbad: D
# bad: CRMbad: QRVObad: OGNbad: BLKbad: IRMbad: ATObad: MASbad: CBbad: CAT
#
#
# bad: CVSbad: FOXA
#
#
# bad: ANSS
#
#
#
#
# bad: LW
#
#
#
#
#
#
#
#
# bad: LRCX
#
#
#
#
#
# bad: CMI
# bad: PH
# bad: LDOS
# bad: WMbad: NSC
# bad: TXN
#
# bad: NI
#
#
#
# bad: APA
#
# bad: MET
#
# bad: WELL
#
#
#
#
#
# bad: IT
#
#
#
#
#
#
#
#
#
# bad: IQV
#
# bad: AMGN
# bad: BEN
#
# bad: CE
#
#
# bad: JNPR
# bad: CTSHbad: STEbad: TRMBbad: ALBbad: SYYbad: MUbad: HES
#
#
#
# bad: L
# bad: MNST
# bad: BRO
#
#
# bad: INCYbad: KMBbad: NXPI
# bad: MMC
# bad: ANTM
#
#
#
#
#
# bad: AFL
#
#
# bad: NDSN
# bad: BA
#
# bad: CHTR
#
#
#
#
#
#
#
#
#
# bad: VMC
#
# bad: TMO
#
# bad: T
#
# bad: HSYbad: EQRbad: AAPLbad: FRCbad: PXDbad: LINbad: MSCI
# bad: GPN
# bad: HUM
# bad: EIX
#
#
#
#
#
#
# bad: TWTR
# bad: LNT
#
# bad: RMD
#
#
#
#
#
# bad: BF-B
#
#
# bad: MRK
#
#
# bad: AAL
#
#
# bad: OTIS
#
# bad: BR
#
# bad: MKTX
#
# bad: RL
#
# bad: AON
#
#
#
#
# bad: SNA
#
# bad: HRLbad: UALbad: PVH
#
#
# bad: NWL
# bad: AKAM
# bad: BKR
# bad: CERN
# bad: XEL
#
# bad: AOS
#
#
#
#
#
#
#
# bad: HII
#
#
#
#
#
# bad: SPGI
#
# bad: EXPEbad: CDNSbad: ICEbad: REbad: ACNbad: FE
#
#
#
# bad: LNC
# bad: NVDA
# bad: SYF
#
#
#
#
# bad: AZObad: AJGbad: KHCbad: LUMNbad: FTNT
#
# bad: FOX
#
#
#
#
#
#
#
# bad: BKNG
# bad: RCL
#
#
#
# bad: UA
#
#
#
#
#
# bad: PGR
#
#
#
#
#
# bad: IPGP
#
#
#
#
# bad: DGX
#
# bad: DLTRbad: REGbad: WY
#
#
# bad: MSI
#
#
#
# bad: CNP
# bad: LMT
# bad: TFC
# bad: DVN
#
# bad: SBAC
# bad: DOW
# bad: CTVAbad: WABbad: BXP
# bad: PPG
#
#
# bad: KMI
#
#
#
#
#
# bad: GS
#
#
#
#
#
# bad: NCLH
# bad: RHIbad: MRNAbad: VRTX
# bad: WTWbad: REGN
#
# bad: VNObad: ZBHbad: ITWbad: PEGbad: BRK-B
# bad: VZbad: CDAYbad: CFGbad: ADBE
#
#
#
#
#
#
#
#
#
#
#
#
# bad: ABC
# bad: COP
#
# bad: USB
#
#
#
#
#
#
#
# bad: WMB
# bad: RJF
#
# bad: DHR
# bad: J
# bad: CMA
#
# bad: NUE
#
# bad: TYL
#
#
# bad: ALGN
#
#
#
# bad: BIO
# bad: PWR
# bad: EMN
# bad: MHK
# bad: AME
#
# [*********************100%***********************]  1 of 1 completedbad: TRVTB
# bad: ANTM
# [*********************100%***********************]  1 of 1 completed
# bad: BAC
#
# bad: MOS
#
# bad: EIX
#
# bad: MMC
#
# bad: MMM
#
#
# bad: NWSA
#
# bad: DVA
#
#
# bad: K
# bad: IEX
#
# bad: DAL
#
#
# bad: RTX
#
# bad: LH
#
# bad: NLSN
#
# bad: PEG
#
# bad: MDT
#
#
#
#
#
# bad: LYV
#
# bad: DOW
#
#
# bad: ROP
#
#
# bad: DHI
#
#
# bad: CNC
#
#
# bad: O
#
# bad: TSN
#
# bad: SYY
#
#
# bad: LLY
#
# bad: NDSN
#
# bad: CZR
#
# bad: FCX
#
# bad: FE
#
# bad: DISH
#
# bad: XRAY
#
#
# bad: MLM
#
# bad: AIG
#
# bad: MCD
# bad: GD
#
# bad: UDRbad: IP
#
# bad: TRMB
#
# bad: AEE
#
# bad: EQIXbad: HUM
#
# bad: FOX
#
#
# bad: EXC
#
# bad: DRE
#
#
# bad: UAL
#
#
# bad: ALB
#
#
#
#
#
#
#
#
# bad: FDX
#
# bad: COO
#
#
#
# bad: WHR
#
#
#
#
#
#
# bad: WEC
#
#
#
#
#
#
#
#
#
# bad: TEL
#
#
#
#
#
#
#
#
#
#
#
#
# bad: AZO
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: NWL
#
# bad: ABC
#
# bad: CRM
#
# bad: ENPH
#
# bad: HRLbad: BXP
#
# bad: NDAQ
# bad: WAB
# bad: KMBbad: BBWIbad: URIbad: FISbad: GRMN
# bad: XYLbad: PHMbad: CMSbad: MSbad: IRMbad: NLOKbad: DGXbad: MOHbad: HII
# bad: UNPbad: AFLbad: EDbad: SCHWbad: BAXbad: ETNbad: LENbad: ODFLbad: PRUbad: CINF
# bad: SWKS
# bad: CTSHbad: DLTRbad: AON
# bad: CLX
# bad: FRT
# bad: ADIbad: WM
# bad: STXbad: PPLbad: EXPD
# bad: DHR
#
#
# bad: CCI
#
# bad: HES
# bad: MHK
#
# bad: RMD
# bad: STE
#
# bad: JCI
# bad: LNT
# bad: REbad: ALGN
# bad: TJX
# bad: BLL
# bad: FDSbad: INCY
#
# bad: VNObad: AMATbad: STZbad: NKEbad: Vbad: GPNbad: MTCH
#
#
#
#
#
#
# bad: PNR
#
#
#
#
#
#
#
#
#
#
#
# bad: CATbad: FB
#
# bad: LNCbad: WTW
#
#
#
#
#
#
# bad: LW
# bad: HBAN
#
#
# bad: TECH
# bad: FTV
#
# bad: PNW
#
# bad: CPRT
#
#
#
# bad: JNPR
#
#
#
#
#
#
#
#
# bad: EBAY
# bad: TSLAbad: EFX
# bad: BR
#
# bad: ADM
#
#
#
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
# bad: WMT
# bad: CSCO
# bad: GNRC
# bad: CARRbad: MARbad: NUE
# bad: MRNA
# bad: TWTR
#
#
#
#
#
#
#
#
#
#
#
# bad: C
#
#
#
#
#
#
#
#
#
#
#
# bad: BMY
#
#
#
#
#
#
#
#
#
#
# bad: MRO
#
# bad: YUM
# bad: PXDbad: QCOMbad: AOS
#
#
# bad: REGbad: LHXbad: ESbad: GILDbad: APTVbad: MSIbad: TERbad: PTCbad: CLbad: JPM
#
# bad: IRbad: AREbad: MUbad: EMNbad: DUKbad: JBHTbad: DXCMbad: BDXbad: EXPE
#
# bad: REGN
# bad: TMUSbad: NXPI
#
# bad: ETSYbad: PLDbad: A
#
#
#
#
#
#
#
#
# bad: LOW
#
#
#
#
#
#
#
#
# bad: UAAbad: MPWR
# bad: LUMN
# bad: OTIS
#
#
#
#
#
#
# bad: RSGbad: PH
#
#
#
# bad: CB
#
#
#
# bad: ETR
#
#
#
#
#
#
#
#
# bad: PFE
#
#
#
#
#
#
#
#
#
# bad: BWAbad: FISV
# bad: NEM
# bad: EPAM
#
#
#
#
#
#
# bad: PAYX
#
#
# bad: EOG
#
#
#
#
#
# bad: CDAYbad: USBbad: AIZbad: MTD
# bad: WBA
#
# bad: TYL
#
# bad: INTC
# bad: HLTbad: ROSTbad: KMXbad: IPGP
# bad: HPEbad: KRbad: CPBbad: GS
#
# bad: CTXS
# bad: VRTX
# bad: TXN
#
#
#
#
# bad: NCLHbad: TXTbad: ROL
# bad: OMC
# bad: MAS                  Open        High         Low       Close   Adj Close  \
# Date
# 2000-06-23   19.500000   23.625000   18.500000   22.000000   22.000000
# 2000-06-26   21.750000   21.875000   20.875000   21.875000   21.875000
# 2000-06-27   21.937500   21.937500   21.125000   21.562500   21.562500
# 2000-06-28   21.625000   21.687500   20.625000   21.562500   21.562500
# 2000-06-29   21.500000   21.500000   21.187500   21.187500   21.187500
# ...                ...         ...         ...         ...         ...
# 2022-04-26  249.809998  253.369995  230.619995  231.669998  231.669998
# 2022-04-27  234.289993  241.660004  232.449997  238.949997  238.949997
# 2022-04-28  235.000000  245.910004  234.610001  242.169998  242.169998
# 2022-04-29  242.220001  252.059998  240.539993  241.509995  241.509995
# 2022-05-02  239.759995  245.910004  234.800003  245.880005  245.880005
#
#              Volume
# Date
# 2000-06-23  7986500
# 2000-06-26  1005000
# 2000-06-27   421000
# 2000-06-28   567500
# 2000-06-29   140300
# ...             ...
# 2022-04-26  1170000
# 2022-04-27   950200
# 2022-04-28   819600
# 2022-04-29   640500
# 2022-05-02   836200
#
# [5499 rows x 6 columns]
#
# bad: HST
# bad: MRKbad: RJF
#
#
#
# bad: WRBbad: HAS
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-03-17    0.000000    5.437500    5.250000    5.250000    1.908676
# 1980-03-18    0.000000    5.208333    5.083333    5.208333    1.893528
# 1980-03-19    0.000000    5.291667    5.250000    5.250000    1.908676
# 1980-03-20    0.000000    5.291667    5.250000    5.250000    1.908676
# 1980-03-21    0.000000    5.291667    5.208333    5.291667    1.923826
# ...                ...         ...         ...         ...         ...
# 2022-04-26  140.460007  142.080002  138.080002  138.179993  138.179993
# 2022-04-27  138.779999  140.779999  137.580002  139.139999  139.139999
# 2022-04-28  126.900002  130.779999  125.199997  127.129997  127.129997
# 2022-04-29  125.709999  129.490005  119.849998  120.150002  120.150002
# 2022-05-02  119.550003  124.279999  118.900002  122.809998  122.809998
#
#              Volume
# Date
# 1980-03-17    70800
# 1980-03-18   100200
# 1980-03-19    45000
# 1980-03-20    79800
# 1980-03-21   288000
# ...             ...
# 2022-04-26  2705100
# 2022-04-27  2391300
# 2022-04-28  5689300
# 2022-04-29  5290500
# 2022-05-02  3138500
#
# [10623 rows x 6 columns]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: WELLbad: NFLX                  Open        High         Low       Close   Adj Close  \
# Date
# 1980-03-17    0.000000    0.512028    0.497999    0.501506    0.192751
# 1980-03-18    0.000000    0.512028    0.494492    0.505013    0.194099
# 1980-03-19    0.000000    0.515535    0.503260    0.512028    0.196795
# 1980-03-20    0.000000    0.513781    0.499753    0.499753    0.192078
# 1980-03-21    0.000000    0.506767    0.499753    0.505013    0.194099
# ...                ...         ...         ...         ...         ...
# 2022-04-26  118.610001  119.639999  116.970001  116.970001  116.970001
# 2022-04-27  117.290001  118.580002  116.129997  116.720001  116.720001
# 2022-04-28  117.550003  118.739998  116.830002  118.010002  118.010002
# 2022-04-29  117.059998  117.769997  113.129997  113.500000  113.500000
# 2022-05-02  113.500000  114.019997  110.279999  112.830002  112.830002
#
#              Volume
# Date
# 1980-03-17  7513463
# 1980-03-18  5303621
# 1980-03-19  2523497
# 1980-03-20  4654925
# 1980-03-21  1333034
# ...             ...
# 2022-04-26  3366300
# 2022-04-27  4178700
# 2022-04-28  4960000
# 2022-04-29  6814600
# 2022-05-02  4905000
#
# [10623 rows x 6 columns]
#
#
#
#
# bad: CDW
#
#
#
# ...
# bad: CME
#
#
#
#
# bad: J
# bad: SPGI
# bad: ATVIbad: AMPbad: FITB
#
#
#
#
# bad: RF
#
# bad: UA
#
# bad: APD
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 1980-10-01    0.000000    2.851852    2.833333    2.833333    1.238189  566325
# 1980-10-02    0.000000    2.814815    2.796296    2.796296    1.222003  106650
# 1980-10-03    0.000000    2.814815    2.777778    2.777778    1.213910   34425
# 1980-10-06    0.000000    2.759259    2.740741    2.740741    1.197725  194400
# 1980-10-07    0.000000    2.703704    2.685185    2.685185    1.173447  423900
# ...                ...         ...         ...         ...         ...     ...
# 2022-04-26  100.519997  102.050003   99.949997  100.029999  100.029999  526100
# 2022-04-27  100.269997  101.889999  100.000000  100.550003  100.550003  373600
# 2022-04-28  101.449997  101.879997   99.809998  101.790001  101.790001  451400
# 2022-04-29  101.209999  101.300003   97.900002   98.080002   98.080002  479100
# 2022-05-02   98.699997   99.500000   96.459999   98.099998   98.099998  353600
#
# [10485 rows x 6 columns]
#
#
# bad: MCO
#
#
#
#
# bad: IBM
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: IQV
#
#
#
#
#
# bad: BBY
#
#
#
#
#
# bad: EQR
# bad: EMRbad: FOXA
#
#
#
# bad: LUV
# bad: MGM
#
# bad: AMZNbad: ATObad: NTAP
# bad: DDbad: TPRbad: ECLbad: NSCbad: CVSbad: L
# bad: PWR
# bad: RLbad: ALL
#
#
# bad: PEPbad: DOVbad: CPTbad: TFX
#
# bad: ITWbad: MAAbad: SYFbad: PVH
#
# bad: IPG
# bad: NTRSbad: BRObad: ICE
#
# bad: AEP
#
#
# bad: PKGbad: KEYbad: TAPbad: SEE
#
#
#
#
#
#
#
#
# bad: TMObad: TFC
#
#
# bad: IFF
#
#
# bad: CAG
#
#
#
#
# bad: ADSK
#
#
#
#
#
#
#
# bad: FTNT
#
# bad: ALK
#
# bad: SYK
#
# bad: CBRE
#
# bad: ILMN
#
#
#
#
#
#
# bad: HOLX
#
#
#
#
#
#
# bad: COF
#
# bad: UHS
#
#
#
#
#
#
#
# bad: HPQ
#
# bad: ANET
#
#
#
#
#
#
#
# bad: LMT
#
#
# bad: APH
# bad: BKR
#
# bad: IVZbad: RHI
# bad: ADBE
#
#
#
#
# bad: CCLbad: ZBHbad: XELbad: ACNbad: DFSbad: VMC
#
#
#
# bad: PARAbad: STTbad: CFG
#
#
#
#
#
#
# bad: APA
# bad: EA
# bad: AAL
# bad: VLO
# bad: BA
# bad: AESbad: CNP
# bad: IT
# bad: TDGbad: CEG
# bad: MTB
# bad: SNPS
#
# bad: CTVA
# bad: PGR
#
#
# bad: SJMbad: BKNG
# bad: PPG
# bad: NOC
# bad: KEYS
# bad: KHC
#
# bad: ADP
# bad: TT
#
#
#
#
# bad: KIM
#
#
# bad: MDLZ
# bad: MO
#
#
#
#
#
# bad: RCL
#
# bad: HWM
#
#
#
# bad: QRVO
# bad: EW
# bad: VZ
# bad: SBNY
#
#
#
# bad: WFC
# bad: BLK
#
#
# bad: MET
# bad: DVN                 Open       High        Low      Close  Adj Close    Volume
# Date
# 1980-03-17   0.000000   3.302083   3.125000   3.145833   3.145833    219600
# 1980-03-18   0.000000   3.125000   2.937500   3.031250   3.031250    727200
# 1980-03-19   0.000000   3.083333   3.020833   3.041667   3.041667    295200
# 1980-03-20   0.000000   3.062500   3.010417   3.010417   3.010417    159600
# 1980-03-21   0.000000   3.020833   2.906250   2.916667   2.916667    130800
# ...               ...        ...        ...        ...        ...       ...
# 2022-04-26  89.739998  90.120003  85.080002  85.160004  85.160004  89127400
# 2022-04-27  84.250000  87.900002  84.019997  84.910004  84.910004  83125100
# 2022-04-28  86.669998  90.580002  84.779999  89.639999  89.639999  91495400
# 2022-04-29  88.050003  91.790001  85.379997  85.519997  85.519997  82568500
# 2022-05-02  85.660004  90.370003  85.320000  89.839996  89.839996  98304100
#
# [10623 rows x 6 columns]
#
#
#
#
#
# bad: BRK-B
# bad: CERN
#
#
# bad: CE
# bad: OGN
#
#
# bad: HSY
#
#
#
# bad: AMT
#
# bad: KLAC
# bad: UNH
#
#
#
#
# bad: SPGbad: WYNN
# bad: CHRW
#
# bad: LINbad: LYBbad: CMA
# bad: COP
# bad: EL
#
#
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1985-11-20    0.000000    0.381944    0.375000    0.375000    0.159474
# 1985-11-21    0.000000    0.368056    0.354167    0.354167    0.150614
# 1985-11-22    0.000000    0.368056    0.361111    0.361111    0.153567
# 1985-11-25    0.000000    0.361111    0.354167    0.354167    0.150614
# 1985-11-26    0.000000    0.361111    0.354167    0.354167    0.150614
# ...                ...         ...         ...         ...         ...
# 2022-04-26  197.139999  197.440002  193.520004  193.610001  193.610001
# 2022-04-27  194.220001  195.300003  191.479996  191.830002  191.830002
# 2022-04-28  193.389999  195.940002  192.110001  194.630005  194.630005
# 2022-04-29  194.220001  195.479996  189.020004  189.580002  189.580002
# 2022-05-02  188.970001  191.979996  186.979996  190.360001  190.360001
#
#              Volume
# Date
# 1985-11-20  5373000
# 1985-11-21  6557400
# 1985-11-22   415800
# 1985-11-25   626400
# 1985-11-26   505800
# ...             ...
# 2022-04-26   336200
# 2022-04-27   500400
# 2022-04-28   403100
# 2022-04-29   442500
# 2022-05-02   558200
#
# [9186 rows x 6 columns]
#
# bad: CDNS
#
#
# bad: CTAS
#
#
# bad: AMGN
#
#
#
#
#
# bad: HD
#
#
# bad: IDXX
#
#
#
#
#
#
#
#
# bad: HAL
#
# bad: BK
#
#
#
#
#
#
#
# bad: BEN
#
#
# bad: SBUX
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: PG
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: MKTX
#
#
# bad: AAP
#
#
#
# bad: GIS
#
#
# bad: AXP
# bad: WRKbad: LDOSbad: DLRbad: BF-B
#
# bad: NWS
#
# bad: XOM
# bad: EVRGbad: BIObad: ZBRAbad: TTWO
#
#
#
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 1981-12-31   3.703581   3.741763   3.665400   3.665400   0.312697   220985
# 1982-01-04   3.703581   3.741763   3.665400   3.741763   0.319212   365035
# 1982-01-05   3.818125   3.932669   3.665400   3.703581   0.315954   666558
# 1982-01-06   3.703581   3.741763   3.665400   3.703581   0.315954   500900
# 1982-01-07   3.703581   3.703581   3.665400   3.665400   0.312697   171550
# ...               ...        ...        ...        ...        ...      ...
# 2022-04-26  74.750000  75.419998  73.720001  73.739998  73.739998  6880500
# 2022-04-27  73.900002  74.519997  72.849998  73.480003  73.480003  6407600
# 2022-04-28  74.639999  76.139999  73.900002  75.580002  75.580002  5702100
# 2022-04-29  75.290001  75.370003  73.269997  73.389999  73.389999  8189500
# 2022-05-02  74.040001  74.269997  72.129997  73.209999  73.209999  6371900
#
# [10170 rows x 6 columns]bad: AME
# bad: NIbad: NOWbad: CTRAbad: HONbad: DTEbad: ISRGbad: NVDAbad: ORLYbad: ABMDbad: F
# bad: MSCIbad: GLWbad: WY
# bad: UPS
# bad: MA
# bad: T
# bad: AVGO
#
#
#
# bad: GM
# bad: PSA
# bad: ZION
#
#
#
# bad: AVY
# bad: TGT
#
# bad: SBACbad: GOOGL
#
#
# bad: PEAK
#
# bad: COST
#
# bad: MNST
#
# bad: VFC
# bad: FANGbad: PMbad: SIVBbad: LVS
#
# bad: CMI
# bad: NRGbad: CVXbad: DISbad: GEbad: WMB
# bad: SLB
#
# bad: SEDG
#
# bad: BIIB
#
# bad: HCA
#
#
# bad: CHDbad: OKE
#
#
#
#
#
# bad: AKAM
#
#              Open       High        Low      Close  Adj Close    Volume
# Date
# 1980-03-17   0.00   1.555556   1.444444   1.444444   1.230115      2700
# 1980-03-18   0.00   1.481481   1.370370   1.370370   1.167032     21600
# 1980-03-19   0.00   1.444444   1.333333   1.333333   1.135491      4050
# 1980-03-20   0.00   1.444444   1.333333   1.333333   1.135491      6750
# 1980-03-21   0.00   1.444444   1.333333   1.333333   1.135491      4050
# ...           ...        ...        ...        ...        ...       ...
# 2022-04-26  10.32  10.500000  10.250000  10.290000  10.290000  14309600
# 2022-04-27  10.32  10.490000  10.180000  10.360000  10.360000   9515200
# 2022-04-28  10.38  10.540000  10.260000  10.490000  10.490000  12178300
# 2022-04-29  10.45  10.610000  10.270000  10.330000  10.330000  13224400
# 2022-05-02  10.35  10.450000  10.030000  10.210000  10.210000  13070600
#
# [10623 rows x 6 columns]bad: BSX
#
#
#
#
# bad: EXR
# bad: CAHbad: FRC
# bad: HSICbad: D
#
#
#
# bad: FFIVbad: KMI
# bad: CHTR
# bad: NEEbad: MCHP
#
#
#
# bad: CMCSAbad: SNA
#
#
#
#
#
#
#
#
# bad: NVR
#
# bad: DPZ
# bad: AAPL
#
#
# bad: WST
#
# bad: LRCX
#
#
# bad: PKIbad: WAT
#
# bad: MCK
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
# bad: ABMD
#
#
#
# bad: EXR
#
#
# bad: ISRG
#
#
# bad: PTC
#
#
# bad: DIS
# bad: CSCO
# bad: SBNY
# bad: ADM
# bad: APA
# bad: ODFL
#
#
#
# bad: EW
#
#
# bad: BAX
# bad: KMX
#
# bad: FMC
# bad: HASbad: SWKbad: LYBbad: VFC
#
# bad: FAST
#
#
# bad: MCD
#
# bad: EOG
#
# bad: LIN
#
#
# bad: PPG
#
#
#
#
#
#
#
# bad: PNR
#
#
# bad: NEM
#
# bad: ALB
# bad: SPG
#
# bad: ES
# bad: KLAC
#
#
#
#
#
#
#
# bad: FCX
# bad: HD
# bad: EMRbad: OKEbad: CMCSAbad: CINF
#
#
#
# bad: IPG
# bad: LLYbad: TAP
# bad: OMC
# bad: CCL
# bad: ROSTbad: TRVbad: CLbad: QRVO
# bad: KEYbad: WEC
#
#
#
#
# bad: PPL
#
# bad: ENPH
#
#
#
#
#
#
#
#
#
#
# bad: MMM
# bad: SObad: KEYS
#
#
# bad: WYNN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: TPRbad: PLDbad: AAPLbad: TDYbad: MDLZbad: BMY
#
# bad: AMDbad: ZION
# bad: DUKbad: SEE
#
#
#
# bad: NWLbad: GLbad: MPWR
# bad: XEL
#
#
#
#
#
#
# bad: VTRS
#
#
#
#
#
#
#
#
#
# bad: PM
#
#
#
#
#
# bad: HUM
# bad: GRMNbad: SYK
#
#
# bad: WMTbad: ADI
# bad: MSbad: ABT
#
# bad: CMS
# bad: AEPbad: LNTbad: ETN
# bad: NTAPbad: INCY
# bad: CTAS
#
#
# bad: BRO
#
#
#
#
#
#
#
#
# bad: JKHY
#
#
#
#
# bad: COST
# bad: CERN
#
#
#
#
#
# bad: PEAKbad: BSXbad: PFEbad: BBYbad: Dbad: LDOS
# bad: FDX
# bad: TGT
# bad: DAL
# bad: CTRA
#
#
#
#
#
#
#
#
# bad: RL
# bad: CEG
#
# bad: HBAN
# bad: AKAM
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: SNPS
# bad: WBAbad: EQIXbad: MNST
# bad: ETSYbad: PKIbad: OGNbad: HONbad: DOV
# bad: KMBbad: URI
# bad: XRAY
#
# bad: LYV
#
#
# bad: Fbad: CHRW
#
#
# bad: BK
# bad: FTVbad: BIO
#
#
# bad: MTB
#
#
#
#
#
# bad: FB
#
#
# bad: MOH
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: WFC
#
# bad: PG
#
# bad: HPEbad: IVZbad: V
# bad: CTSHbad: HWMbad: DLRbad: EXPDbad: PAYXbad: EIXbad: ITbad: SEDGbad: HRL
# bad: CDW
# bad: EPAM
# bad: INTC
#
# bad: AREbad: SBUX
# bad: DD
#
#
#
# bad: NSC
#
#
#
# bad: FOXAbad: AES
# bad: EQR
#
# bad: WRBbad: ACNbad: MRK
#
#
#
#
#
#
# bad: LW
#
#
# bad: CME
#
#
#
#
#
#
# bad: MRO
# bad: AAL
#
# bad: PHM
#
# bad: HLT
#
#
#
# bad: IQV
#
#
# bad: HST
#
#
#
#
#
#
#
#
#
#
#
# bad: UPS
#
# bad: KMI
#
#
#
# bad: IFF
#
#
#
#
# bad: LVS
#
# bad: ETR
# bad: CTXS
#
#
# bad: WMBbad: APTVbad: NLSN
# bad: CAG
# bad: TFXbad: ECL
# bad: RTX
# bad: TRMB
#
#
#
#
# bad: PEG
#
#
#
#
#
#
# bad: DTE
#
# bad: NEE
#
# bad: WELLbad: ADPbad: REG
# bad: EA
# bad: VZ
# bad: GISbad: NDSNbad: ITW
# bad: EBAY
# bad: AMGNbad: JPM
# bad: DFSbad: DRE
# bad: DHR
# bad: WAT
#
#
#
#
#
#
#
#
#
# bad: IR
#
#
#
# bad: WTW
#
#
# bad: MAR
#
# bad: DLTR
#
# bad: SPGI
#
#
#
#
#
# bad: AAP
#
#
#
#
#
# bad: PRU
#
# bad: DVA
#
#
#
#
#
#
# bad: GE
#
# bad: RSG
#
#
#
# bad: BLKbad: FFIV
# bad: GS
#
#
#
# bad: K
#
#
#
#
# bad: AZObad: AON
#
# bad: MDT
#
#
#
#
#
#
# bad: CNC
#
#
#
#
# bad: MCO
#
#
#
#
#
# bad: ANET
#
#
#
#
# bad: WY
# bad: CARRbad: TMO
# bad: ROPbad: NRGbad: UNH
# bad: NWS
#
# bad: CFG
# bad: STZ
# bad: RJF
#
#
#
# bad: LUVbad: FITBbad: SBACbad: MTDbad: A
# bad: MGMbad: UNP
# bad: XYLbad: NKEbad: CNP
#
# bad: LHbad: PVH
# bad: IPbad: COPbad: MAS
# bad: HII
#
# bad: TEL
# bad: NTRS
#
# bad: BAC
# bad: GNRCbad: BKNG
# bad: FTNTbad: GPNbad: REbad: JCIbad: TTWO
#
# bad: WSTbad: ALGN
#
# bad: HPQbad: IRMbad: VRTX
# bad: MA
# bad: TJX
#
#
# bad: VLO
# bad: CVXbad: ATVI
# bad: DXCM
#
#
#
# bad: EXPEbad: CRL
#
#
# bad: NWSAbad: HES
#
#
#
#
#
# bad: TSLA
#
# bad: TFCbad: ANSS
# bad: AMPbad: CZR
#
# bad: HSICbad: UALbad: L
#
# bad: JNPR
#
#
#
#
#
#
#
#
#
#
#
#
# bad: UAbad: TERbad: CDNSbad: ILMN
#
#
#
# bad: CPB
#
# bad: NUE
#
#
#
#
#
#
#
#
#
#
# bad: BA
#
#
#
# bad: PEP
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
# bad: AJG
# bad: O
# bad: DHI
# bad: TYL
#
#
#
# bad: FANG
# bad: MSCI
# bad: KIM
# bad: NVDA
#
# bad: AME
#
#
#
#
#
#
#
#
# bad: HALbad: BWA
# bad: MLM
#
#
# bad: CAT
# bad: AOSbad: TTbad: WM
# bad: CCIbad: JBHT
#
#
# bad: C
# bad: KHCbad: PWRbad: SNA
#
#
#
#
#
#
# bad: AIGbad: STE
# bad: AMZN
#
#
#
#
#
#
#
#
#
#
# bad: WRK
# bad: EMN
#
#
#
#
#
#
#
#
#
#
# bad: AMATbad: GDbad: CMIbad: TDGbad: FE
# bad: EFX
# bad: REGN
# bad: HOLX
# bad: QCOM
# bad: USB
#
#
# bad: SCHWbad: MTCHbad: VNObad: ANTM
#
#
#
#
#
# bad: CEbad: IBM
#
#
# bad: COO
#
#
#
#
#
#
#
#
# bad: BRK-B
#
# bad: ADSK
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: MRNA
#
# bad: HCA
#
#
#
#
# bad: ORLY
# bad: MHKbad: IEXbad: WABbad: CRMbad: EVRGbad: HSYbad: KRbad: RMDbad: DVNbad: FDSbad: CMAbad: BRbad: TXTbad: ADBEbad: NVRbad: MCKbad: LNCbad: CAHbad: BXP
# bad: IDXXbad: AIZ
# bad: LUMNbad: DOWbad: LMTbad: SIVBbad: AVY
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: T
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: XOMbad: MUbad: CBbad: GOOGLbad: PHbad: COFbad: EXCbad: APDbad: BBWIbad: GMbad: DGXbad: FISVbad: TXNbad: MSIbad: ELbad: PSAbad: CVSbad: NOCbad: FRCbad: ALKbad: MOSbad: SJMbad: SLBbad: AFLbad: WHRbad: MMCbad: DISHbad: GILD
# bad: NLOK
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: ZBRA
#
#
#
#
# bad: PNWbad: LENbad: CHTR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: BDX
#
#
#
#
#
#
#
# bad: AMT
#
#
#
# bad: AVGObad: NFLXbad: CLXbad: ROLbad: OTISbad: FRTbad: AXPbad: GLWbad: RCLbad: APHbad: DPZbad: SYFbad: BKRbad: ZBHbad: LRCXbad: ABCbad: TSNbad: Jbad: FISbad: MCHP
#
# bad: LOWbad: RFbad: NXPIbad: IPGPbad: BENbad: CBRE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: PARA
#
#
#
#
#
# bad: PXD
# bad: UDR
#
#
# bad: CDAY
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: NDAQ
# bad: AEE
# bad: BIIB
# bad: CHD
# bad: MObad: NIbad: TWTR
# bad: UAAbad: SYYbad: PKGbad: MAAbad: CPTbad: CTVAbad: STXbad: STTbad: NOW
#
#
#
#
#
#
#
#
# bad: UHS
#
#
#
# bad: VMCbad: MKTXbad: BF-Bbad: LHXbad: ICEbad: BLLbad: SWKS
#
# bad: ALL
#
#
#
#
#
#
#
# bad: EDbad: RHIbad: CPRT
# bad: YUMbad: FOXbad: ATO
# bad: PGRbad: TECH
#
#
#
#
#
#
#
#
# bad: METbad: NCLH
#
#
# bad: TMUS
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
# bad: EOG
#
# bad: CEG
# [*********************100%***********************]  1 of 1 completed
# bad: STT
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: TT
#
#
# bad: LH
#
#
#
# bad: ICE
# bad: DISHbad: KEYbad: AIG
#
# bad: DLTR
#
#
#
# bad: HBANbad: COO
#
#
# bad: STE
# bad: DVNbad: GD
# bad: SBUX
#
# bad: DDbad: OMC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: SObad: URIbad: JPMbad: IDXXbad: NLSNbad: MAbad: EQIXbad: USBbad: ACNbad: IPG
#
#
#
#
#
#
#
#
#
# bad: BAC
# bad: COP
#
#
#
#
#
#
#
#
#
#
#
#
# bad: CSCObad: CERNbad: AREbad: ANSS
#
# bad: XRAYbad: PPL
#
# bad: SYF
# bad: EA
#
# bad: PVH
# bad: ADMbad: AAL
#
#
#
# bad: MU
#
#
# bad: NRG
#
#
# bad: SPGIbad: BLLbad: CLX
# bad: IBM
#
#
#
#
#
#
# bad: SLBbad: WFCbad: NLOK
#
# bad: JNPR
#
#
#
#
# bad: AJG
#
# bad: ABMD
#
#
# bad: MCHP
# bad: CARR
#
#
#
#
#
#
#
#
#
#
#
# bad: QRVObad: DISbad: KHCbad: TJXbad: TDYbad: BAXbad: VLO
# bad: NDSNbad: BLKbad: STZ
#
#
#
#
#
# bad: UPS
#
#
# bad: FISV
#
#
#
#
#
#
#
# bad: EPAM
#
#
#
#
#
#
#
# bad: IRM
#
# bad: SBAC
#
# bad: NEE
#
# bad: APTV
#
# bad: CAT
# bad: AMDbad: ILMN
# bad: ABC
#
# bad: RCLbad: QCOMbad: ETNbad: JKHYbad: GLW
#
# bad: VZ
#
# bad: EXPD
#
# bad: COST
# bad: ISRG
#
#
# bad: SEE
# bad: TRMB
#
#
# bad: TSLA
#
#
#
#
#
# bad: CVS
# bad: TYL
# bad: HST
#
# bad: FBbad: CE
#
#
#
# bad: PKI
# bad: MPWR
# bad: CDW
#
#
#
# bad: IPGP
#
# bad: V
#
#
#
# bad: UAL
# bad: CB
#
#
#
#
#
#
# bad: HPQ
# bad: ECL
#
#
# bad: FDX
# bad: HII
# bad: TXNbad: RL
# bad: EXPEbad: EIXbad: MO
#
#
#
#
# bad: ROSTbad: WELL
#
#
#
#
#
# bad: NWSbad: AFLbad: AOSbad: LYV
#
#
#
#
# bad: BRK-B
#
#
#
#
# bad: VFCbad: RTX
#
#
# bad: FIS
#
#
#
#
#
#
#
#
#
#
# bad: CHRWbad: REGbad: GNRC
# bad: AMGNbad: PSAbad: AXP
# bad: L
#
#
#
# bad: LUV
# bad: ANTMbad: ALGN
#
#
#
# bad: DLR
# bad: MTB
#
# bad: PG
# bad: IPbad: ADBEbad: INTC
# bad: XOM
#
#
#
#
#
# bad: CBRE
# bad: PKG
#
# bad: WMT
#
#
#
#
# bad: EQRbad: AME
#
# bad: BXP
#
#
# bad: DXCM
#
#
#
# bad: MAS
#
#
#
# bad: FFIV
#
#
#
#
#
# bad: BK
# bad: CRL
# bad: FOXbad: GILD
# bad: MDT
# bad: TECH
#
#
# bad: HON
# bad: JBHT
# bad: SPGbad: BBY
#
# bad: ODFL
#
#
# bad: LUMN
#
#
# bad: CCL
# bad: ALK
#
#
# bad: FTV
# bad: TMO
#
#
#
#
# bad: SBNY
#
#
# bad: LNCbad: SEDG
# bad: PNR
# bad: MET
# bad: PNW
# bad: OGN
# bad: PTC
#
#
#
#
# bad: DAL
#
#
#
#
#
# bad: MKTX
#
#
#
# bad: AES
# bad: WMB
#
#
# bad: MCD
# bad: XEL
# bad: LVS
# bad: A
# bad: HES
#
# bad: HCA
#
#
# bad: HOLX
#
#
#
# bad: DTE
#
# bad: KMB
# bad: DHI
# bad: WTW
#
#
#
#
#
#
#
#
#
#
# bad: HAL
#
# bad: KLAC
#
#
#
# bad: FTNT
# bad: CAG
# bad: BIObad: LMTbad: GL
# bad: GPNbad: REGN
# bad: BKNGbad: BWA
# bad: IR
#
# bad: FOXA
# bad: ENPHbad: CMSbad: MRObad: FCX
#
#
#
#
#
# bad: AZO
#
#
#
#
#
# bad: MOH
# bad: IQVbad: HPE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: CTXSbad: BA
#
# bad: SWKbad: ADI
# bad: AKAM
# bad: AON
# bad: NCLH
# bad: CNC
#
#
# bad: CINFbad: DUKbad: MDLZbad: NTRSbad: WYNNbad: PRUbad: SYY
#
#
# bad: LLYbad: AIZ
#
#
#
# bad: DFS
#
#
#
#
#
#
#
#
# bad: PEG
#
#
#
#
#
#
#
#
#
# bad: DHRbad: IEX
# bad: DOV
# bad: HUM
# bad: VTRS
# bad: MRNA
#
# bad: MLM
#
# bad: UNH
# bad: WEC
# bad: WHR
# bad: FMC
# bad: LNT
#
# bad: ATO
# [*********************100%***********************]  1 of 1 completedbad: TMUSA
#
#
#
# bad: SNPS
# bad: NWL
#
#
#
# bad: MRK
#
# bad: KR
#
#
#
#
# bad: MS
#
#
# bad: DOWbad: Jbad: SYKbad: UA
# bad: FEbad: BRObad: ADSK
#
# bad: WAB
#
#
#
#
# bad: FITBbad: MGMbad: HRLbad: KMX
# bad: YUM
#
#
#
#
# bad: NSC
#
# bad: GRMN
#
#
#
#
#
#
#
#
#
# bad: WAT
#
# bad: CHTR
#
# bad: LINbad: Kbad: NWSAbad: BSX
#
#
#
#
# bad: BBWIbad: CDAY
#
# bad: VRTX
#
#
# bad: BMY
#
#
# bad: AEEbad: MTD
#
#
#
# bad: SCHWbad: ROPbad: FRC
#
#
#
# bad: CHD
#
#
#
# bad: ABT
# bad: CPB
# bad: STXbad: RMD
#
#
# bad: DGX
#
#
#
#
#
#
# bad: CTSH
# bad: VNO
# bad: WM
#
#
#
# bad: AVGO
# bad: NVDA
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: TDG
# bad: VMCbad: GOOGLbad: BF-Bbad: AMTbad: EXCbad: HSYbad: CMIbad: EFXbad: MOSbad: MMCbad: AMZNbad: APDbad: SIVBbad: AMATbad: PLDbad: OTISbad: ZBHbad: LOWbad: ORLYbad: NOWbad: NVRbad: APHbad: AVYbad: MAAbad: SNAbad: KIMbad: FANGbad: TWTRbad: TAPbad: Obad: CAHbad: CPTbad: SWKSbad: EDbad: DPZbad: FRTbad: LRCXbad: PHbad: FDSbad: NXPIbad: RFbad: BRbad: ROLbad: COFbad: CCIbad: BIIB
# bad: SJM
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completedbad: TAPKA

# %%
historical_stock_data_files = glob.glob(f"C:/Usersfilro/Documents/Stocks/data/SP500_20220430.csv")
highest_day_list = []

for files in historical_stock_data_files:
    price = pd.read_csv(files, index_col="Date", parse_dates=True)
    ticker = os.path.splitext(os.path.basename(files))[0]
    price_close = price[["Close"]]
    highest_day = price_close.idxmax()[0]
    highest_price = price_close.max()[0]
    highest_day_list.append(pd.DataFrame({"highest_day": [highest_day], "ticker": [ticker], "highest_price": highest_price}))
        
    
    
df = pd.concat(highest_day_list).reset_index(drop=True)
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3096/2268266698.py in <module>
#      12
#      13
# ---> 14 df = pd.concat(highest_day_list).reset_index(drop=True)
#      15 print(df.shape)
#      16 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     349
#     350         if len(objs) == 0:
# --> 351             raise ValueError("No objects to concatenate")
#     352
#     353         if keys is None:
#
# ValueError: No objects to concatenate

# %%
# additional info
df["highest_month"] = df["highest_day"].dt.to_period("M")
df = pd.merge(df, sp500_df[["Symbol", "GICS Sector", "GICS Sub-Industry"]], left_on='ticker', right_on='Symbol')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3096/127117888.py in <module>
#       1 # additional info
# ----> 2 df["highest_month"] = df["highest_day"].dt.to_period("M")
#       3 df = pd.merge(df, sp500_df[["Symbol", "GICS Sector", "GICS Sub-Industry"]], left_on='ticker', right_on='Symbol')
#
# NameError: name 'df' is not defined

# %%
df.sort_values("highest_day",ascending=False).head(20)

# %%
industry_value_counts = df[df["highest_day"] >= "2022-04-01"]["GICS Sub-Industry"].value_counts()
fig, ax = plt.subplots(figsize=(20, 8))
ax.bar(industry_value_counts.index, industry_value_counts.values)
ax.set_xticklabels(industry_value_counts.index, rotation=90)
ax.set_xlabel("industry")
ax.set_ylabel("number of stocks")
plt.show()

# %%
display(industry_value_counts[industry_value_counts.index.str.contains("Utilities")])
display(industry_value_counts[industry_value_counts.index.str.contains("Health Care")])
display(industry_value_counts[industry_value_counts.index.str.contains("Insurance")])

# %%
highest_day_count = df.groupby("highest_month").count()
highest_day_count["ticker"].plot()
plt.title("Number of stocks that reached new highs")
plt.ylabel("number of stocks")
plt.show()

# %%
highest_day_count["ticker"].plot(marker=".")
plt.grid(axis='y')
plt.title("Number of stocks that reached new highs")
plt.xlim("2021-01-01","2022-04-30")
plt.ylabel("number of stocks")
plt.show()

# %%
tikcer_list = ["GOOG", "AAPL", "FB", "AMZN", "MSFT", "TSLA", "NVDA"]
df[df["ticker"].isin(tikcer_list)]

# %%
industry_value_counts = df[df["highest_day"] <= "2021-12-31"]["GICS Sub-Industry"].value_counts()
fig, ax = plt.subplots(figsize=(20, 8))
ax.bar(industry_value_counts.index, industry_value_counts.values)
ax.set_xticklabels(industry_value_counts.index, rotation=90)
ax.set_xlabel("industry")
ax.set_ylabel("number of stocks")
plt.show()

# %%
df["in_2022"] = df["highest_day"].map(lambda x: False if x.year < 2022 else True)
value_counts_before_2022 = df[df["in_2022"]==False]["GICS Sub-Industry"].value_counts()
value_counts_2022 = df[df["in_2022"]==True]["GICS Sub-Industry"].value_counts()
value_counts_before_2022.name = "~2021"
value_counts_2022.name = "2022"
comparison_df = pd.concat([value_counts_2022, value_counts_before_2022], axis=1)
comparison_df = comparison_df.fillna(0)
comparison_df.head()

# %%
fig, ax = plt.subplots(figsize=(20, 8))
comparison_df.plot(kind='bar', stacked=True, ax=ax)
ax.set_xlabel("industry")
ax.set_ylabel("number of stocks")
plt.show()
